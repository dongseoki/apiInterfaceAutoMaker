# %%
import json
import os

# %%
def getApiMethods(apiDatas, key):
    return list(apiDatas[key].keys())

def getApiName(apiDatas, key, apiMN):
    apiItem = apiDatas[key][apiMN]
    if 'summary' in apiItem:
        return apiItem['summary']
    else :
        return key

def getApiDesc(apiDatas, key, apiMN):
    apiItem = apiDatas[key][apiMN]
    if 'description' in apiItem:
        return apiItem['description']
    else :
        return ''

def printAPIInterface(relPath, fileName):
    f = open(relPath+'/' +fileName, encoding='utf8')
    data =json.load(f)
    apiDatas = data['paths']
    for key in sorted(list(data['paths'].keys())):
        # print(key)
        apiMethodList = getApiMethods(apiDatas, key)
        for apiMN in apiMethodList:
            apiName = getApiName(apiDatas, key, apiMN)
            apiDesc = getApiDesc(apiDatas, key, apiMN)
            print('{}\t{}\t{}\t{}\t{}'.format(fileName.split('.')[0], apiName, apiMN, apiDesc, key))

# %%
relPath = './jsonDatas'
file_list = os.listdir(relPath)
for file_name in file_list:
    printAPIInterface(relPath, file_name)
# Out:
# banner-api	Banner Contents 목록 조회	get	Banner Contents 목록 조회	/banner/ctnt/{projectCd}/{siteId}
# banner-api	Banner Contents 상세 조회	get	Banner Contents 상세 조회	/banner/ctnt/{projectCd}/{siteId}/{bannerNo}
# banner-api	Banner 노출수 증가	patch	Banner 노출수 증가	/banner/increase-dsp-cnt
# banner-api	Banner 목록 조회	get	Banner 목록 조회	/banner/{projectCd}/{siteId}
# banner-api	Banner 상세 조회	get	Banner 상세 조회	/banner/{projectCd}/{siteId}/{bannerNo}
# banner-api	TB Banner 목록 조회	get	TB Banner 목록 조회	/tb/banner
# banner-api	TB Banner 등록	post	TB Banner 등록	/tb/banner
# banner-api	TB Banner Detail 목록 조회	get	TB Banner Detail 목록 조회	/tb/banner/detail
# banner-api	TB Banner Detail 등록	post	TB Banner Detail 등록	/tb/banner/detail
# banner-api	TB Banner Detail Sub 목록 조회	get	TB Banner Detail Sub 목록 조회	/tb/banner/detail-sub
# banner-api	TB Banner Detail Sub 등록	post	TB Banner Detail Sub 등록	/tb/banner/detail-sub
# banner-api	TB Banner Detail Sub 단건 조회	get	TB Banner Detail Sub 단건 조회	/tb/banner/detail-sub/{bannerDetailSubSeq}
# banner-api	TB Banner Detail Sub 삭제	delete	TB Banner Detail Sub 삭제	/tb/banner/detail-sub/{bannerDetailSubSeq}
# banner-api	TB Banner Detail Sub 수정	patch	TB Banner Detail Sub 수정	/tb/banner/detail-sub/{bannerDetailSubSeq}
# banner-api	TB Banner Detail 단건 조회	get	TB Banner Detail 단건 조회	/tb/banner/detail/{bannerNo}/{langCd}
# banner-api	TB Banner Detail 삭제	delete	TB Banner Detail 삭제	/tb/banner/detail/{bannerNo}/{langCd}
# banner-api	TB Banner Detail 수정	patch	TB Banner Detail 수정	/tb/banner/detail/{bannerNo}/{langCd}
# banner-api	TB Banner 단건 조회	get	TB Banner 단건 조회	/tb/banner/{bannerNo}
# banner-api	TB Banner 삭제	delete	TB Banner 삭제	/tb/banner/{bannerNo}
# banner-api	TB Banner 수정	patch	TB Banner 수정	/tb/banner/{bannerNo}
# board-api	게시판 조회	get	게시판을 조회합니다.	/admin/board
# board-api	게시판 등록	post	게시판을 추가합니다.	/admin/board
# board-api	게시판 수정	patch	게시판을 수정합니다.	/admin/board
# board-api	게시판 조회	get	게시판을 조회합니다.	/admin/board/{boardNo}
# board-api	게시판 삭제	delete	게시판을 삭제합니다.	/admin/board/{boardNo}
# board-api	게시글 목록 조회	get	게시글 목록을 조회합니다.	/admin/post
# board-api	댓글 추가	post	댓글을 추가합니다.	/admin/post/comment
# board-api	댓글 삭제	delete	댓글을 삭제합니다.	/admin/post/comment/{commentNo}
# board-api	댓글 수정	patch	댓글을 수정합니다.	/admin/post/comment/{commentNo}
# board-api	댓글 목록 조회	get	댓글 목록을 조회합니다.	/admin/post/comment/{postNo}
# board-api	엑셀 다운로드	get	엑셀로 다운로드합니다.	/admin/post/excel
# board-api	게시글 조회	get	게시글을 조회합니다.	/admin/post/{postNo}
# board-api	게시글 삭제	delete	게시글을 삭제합니다.	/admin/post/{postNo}
# board-api	게시글 수정	patch	게시글을 수정합니다.	/admin/post/{postNo}
# board-api	게시판 목록 조회	get	게시판 목록을 조회합니다.	/board
# board-api	게시판 조회	get	게시판을 조회합니다.	/board/{boardNo}
# board-api	버킷 목록 조회	get	버킷 목록을 조회합니다.	/ceph/sample/bucket
# board-api	버킷 생성	post	버킷을 생성합니다.	/ceph/sample/bucket/{bucket}
# board-api	버킷 삭제	delete	버킷을 삭제합니다.	/ceph/sample/bucket/{bucket}
# board-api	더미 파일 생성(테스트용)	post	더미 파일을 생성합니다.(테스트용-파일의 업로드/다운로드는 독립적으로 처리하고, 버킷의 객체<->파일 간에 변환하도록 함)	/ceph/sample/dummy-file/{file}
# board-api	객체 목록 조회	get	버킷의 객체 목록을 조회합니다.	/ceph/sample/object/{bucket}
# board-api	객체 삭제	delete	버킷의 객체를 삭제합니다.	/ceph/sample/object/{bucket}/{key}
# board-api	객체 읽기	get	버킷의 객체를 파일로 읽습니다.(버킷의 객체->파일로 저장)	/ceph/sample/object/{bucket}/{key}/{file}
# board-api	객체 쓰기	post	파일을 버킷의 객체로 씁니다.(파일->버킷의 객체로 저장)	/ceph/sample/object/{bucket}/{key}/{file}
# board-api	팝업 추가	post	팝업을 추가합니다.	/popup
# board-api	팝업 수정	patch	팝업을 수정합니다.	/popup
# board-api	현재 활성화된 팝업 목록 조회	post	현재 활성화된 팝업 목록을 조회합니다.	/popup/activeList
# board-api	팝업 목록 조회	post	팝업 목록을 조회합니다.	/popup/list
# board-api	팝업 조회	get	팝업를 조회합니다.	/popup/{popupNo}
# board-api	팝업 삭제	delete	팝업을 삭제합니다.	/popup/{popupNo}
# board-api	게시글 목록 조회	get	게시글 목록을 조회합니다.	/post
# board-api	게시글 추가	post	게시글을 추가합니다.	/post
# board-api	게시글 리스트 삭제	delete	게시글을 삭제합니다.	/post
# board-api	게시글 수정	patch	게시글을 수정합니다.	/post
# board-api	댓글 추가	post	댓글을 추가합니다.	/post/comment
# board-api	댓글 상세보기	get	댓글을 조회합니다.	/post/comment/{commentNo}
# board-api	댓글 삭제	delete	댓글을 삭제합니다.	/post/comment/{commentNo}
# board-api	댓글 수정	patch	댓글을 수정합니다.	/post/comment/{commentNo}
# board-api	상담 목록 조회	get	상담 목록을 조회합니다.	/post/consulting
# board-api	행사만들기 상담 등록	post	행사만들기 상담을 등록합니다..	/post/consulting
# board-api	상담내역 조회	get	상담을 조회합니다.	/post/consulting/{postNo}
# board-api	공지사항 목록 조회	get	공지사항 목록을 조회합니다.	/post/notice/{boardNo}
# board-api	게시글 조회	get	게시글을 조회합니다.	/post/{postNo}
# board-api	게시글 삭제	delete	게시글을 삭제합니다.	/post/{postNo}
# board-api	댓글 목록 조회	get	댓글 목록을 조회합니다.	/post/{postNo}/comment
# board-api	이전글, 다음글 조회	get	게시글 목록을 조회합니다.	/post/{postNo}/pre-next
# board-api	/redis/sample/cacheable	get		/redis/sample/cacheable
# board-api	/redis/sample/get	get		/redis/sample/get
# board-api	/redis/sample/put	get		/redis/sample/put
# board-api	이메일 수집	post	이메일을 수집합니다.	/subscribe
# board-api	티저 신청 목록	post	신청한 이메일 목록입니다.	/subscribe/list
# board-api	게시글 목록	get	게시글을 목록을 불러옵니다.	/tb/post
# board-api	게시글 정보	get	게시글을 정보를 불러옵니다.	/tb/post/{postNo}
# board-api	버전 조회	get	버전을 조회합니다.	/version
# category-api	/add/category/{projectCd}/{siteId}	post	공통 카테고리 복제	/add/category/{projectCd}/{siteId}
# category-api	공통코드(Category) 목록 조회	get	공통코드(Category) 목록 조회	/category/{projectCd}/{siteId}
# category-api	공통코드(Category) 상세 조회	get	공통코드(Category) 상세 조회	/category/{projectCd}/{siteId}/{masterCd}
# category-api	TB 공통코드(Category) Master 목록 조회	get	TB 공통코드(Category) Master 목록 조회	/tb/category
# category-api	TB 공통코드(Category) Master 등록	post	TB 공통코드(Category) Master 등록	/tb/category
# category-api	TB 공통코드(Category) Detail 목록 조회	get	TB 공통코드(Category) Detail 목록 조회	/tb/category/detail
# category-api	TB 공통코드(Category) Detail 등록	post	TB 공통코드(Category) Detail 등록	/tb/category/detail
# category-api	국가코드 조회 api	get	전체 또는 상세 국가 코드를 조회한다	/tb/category/detail/nation
# category-api	TB 공통코드(Category) Detail 단건 조회	get	TB 공통코드(Category) Detail 단건 조회	/tb/category/detail/{projectCd}/{siteId}/{masterCd}/{detailCd}/{langCd}
# category-api	TB 공통코드(Category) Detail 삭제	delete	TB 공통코드(Category) Detail 삭제	/tb/category/detail/{projectCd}/{siteId}/{masterCd}/{detailCd}/{langCd}
# category-api	TB 공통코드(Category) Detail 수정	patch	TB 공통코드(Category) Detail 수정	/tb/category/detail/{projectCd}/{siteId}/{masterCd}/{detailCd}/{langCd}
# category-api	TB 공통코드(Category) Master 단건 조회	get	TB 공통코드(Category) Master 단건 조회	/tb/category/{projectCd}/{siteId}/{masterCd}
# category-api	TB 공통코드(Category) Master 삭제	delete	TB 공통코드(Category) Master 삭제	/tb/category/{projectCd}/{siteId}/{masterCd}
# category-api	TB 공통코드(Category) Master 수정	patch	TB 공통코드(Category) Master 수정	/tb/category/{projectCd}/{siteId}/{masterCd}
# common-api2	차단기록 조회	get	차단기록을 조회합니다.	/block
# common-api2	신고자 차단	post	신고자를 차단합니다.	/block
# common-api2	차단 조회	get	차단여부를 조회합니다.	/block/getBlock
# common-api2	신고자 차단해제	post	신고자 차단을 해제합니다.	/block/unblock/{blockNo}
# common-api2	CSV 파일 다운로드	post	CSV 파일을 다운로드 합니다.<br/>* Swagger에서는 한글깨짐 현상이 발생합니다.<br/>* Api 호출시에는 정상적으로 작동합니다.	/csv/download
# common-api2	파일 목록 조회	get		/file
# common-api2	멀티 파일 등록	post	파일을 등록합니다. <br/> 등록하는 파일 개수와 파일 설명 목록의 개수가 같아야 합니다.<br/> 설명을 넣고 싶지 않다면 null 값을 넣어주세요.	/file
# common-api2	그룹 이미지 삭제	delete		/file
# common-api2	개별 파일 삭제 (PK)	delete		/file/del/{attachNo}
# common-api2	파일 다운로드(attachNo)	get		/file/download/index/{attachNo}
# common-api2	오투미트 전용 파일 다운로드(PK)	get		/file/download/index/{projectCd}/{siteId}/{attachNo}
# common-api2	파일 다운로드(attachCd)	get		/file/download/{attachCd}
# common-api2	오투미트 전용 파일 다운로드	get		/file/download/{projectCd}/{siteId}/{attachCd}
# common-api2	파일 첨부 그룹 코드별 목록 조회	get		/file/group/{attachGrpCd}
# common-api2	파일 그룹 코드별 삭제	delete		/file/group/{attachGrpCd}
# common-api2	그룹 이미지 삭제	delete		/file/group/{refId}/{refKey}
# common-api2	이미지 등록	post	파일을 등록합니다.	/file/image
# common-api2	이미지 조회	get	이미지 경로를 출력합니다.	/file/image/{attachCd}
# common-api2	파일 정보만 수정	patch		/file/info/{attachCd}
# common-api2	단일 파일 등록	post	단일 파일 등록	/file/single
# common-api2	개별 파일 상세정보 조회	get		/file/{attachCd}
# common-api2	개별 파일 삭제	delete		/file/{attachCd}
# common-api2	파일 단일 정보 수정	patch		/file/{attachCd}
# common-api2	/ftp/upload	post		/ftp/upload
# common-api2	좋아요 목록 조회	get	좋아요 조회	/like
# common-api2	좋아요 조회	get	refKey 값으로 그룹핑 조회, token 값 넘기면 내 좋아요 여부 확인 가능	/like/count
# common-api2	좋아요 및 평점 등록 및 취소	post	좋아요 및 평점 등록 및 취소, 등록 true 리턴, 취소는 false 리턴	/like/toggle
# common-api2	/redis/cacheable	get		/redis/cacheable
# common-api2	/redis/get	get		/redis/get
# common-api2	/redis/put	get		/redis/put
# common-api2	신고목록 조회	get	신고목록을 조회합니다.	/report
# common-api2	신고하기	post	게시물을 신고합니다.	/report
# common-api2	블라인드 등록 및 취소	post	게시물 블라인드 처리 및 취소	/report/blind
# common-api2	신고횟수 조회	get	신고횟수를 조회합니다.	/report/count
# common-api2	신고자 처리완료	patch	신고자를 처리합니다.	/report/process/{reportNo}
# common-api2	신고 개별 조회	get	신고를 개별 조회합니다.	/report/{reportNo}
# common-api2	약관 목록 조회	get	약관 목록을 조회합니다.	/terms
# common-api2	약관 추가	post	약관을 추가합니다.	/terms
# common-api2	약관 수정	patch	약관을 수정합니다.	/terms
# common-api2	유저 약관동의 목록 조회	get		/terms-history
# common-api2	유저 약관동의 등록	post		/terms-history
# common-api2	유저 약관동의 정보 수정	patch		/terms-history
# common-api2	유저 약관동의 등록 (멀티)	post		/terms-history/multi
# common-api2	유저 약관동의 개별조회	get		/terms-history/{historyNo}
# common-api2	유저 약관동의 정보 삭제	delete		/terms-history/{historyNo}
# common-api2	약관 조회	get	약관을 조회합니다.	/terms/{termsNo}
# common-api2	약관 삭제	delete	약관을 삭제합니다.	/terms/{termsNo}
# consulting-api	계정미팅스케줄 (Block) 등록 	post	계정미팅스케줄 (Block) 등록합니다.	/account-meeting/schdul/block
# consulting-api	계정미팅스케줄 조회	get	계정미팅스케줄 조회하여 반환합니다.	/account-meeting/schdul/{schdulNo}/{selUserNo}
# consulting-api	해당 기업 상담원 조회	get	기업의 상담원을 조회하여 반환합니다.	/account/*
# consulting-api	/example/list	post		/example/list
# consulting-api	미팅 입장 목록 조회	get	미팅 입장 목록을 조회합니다.	/meeting-entrance
# consulting-api	미팅확정일자 목록 조회	get	미팅확정일자 목록을 조회합니다.	/meeting-entrance/date
# consulting-api	미팅 링크 저장	patch	미팅 링크를 저장합니다.	/meeting-entrance/link/{choiceNo}
# consulting-api	미팅 결과 제출	post	미팅 결과를 제출합니다.	/meeting-entrance/survey/regist-survey-result
# consulting-api	화상상담 생성	post	화상상담을 생성합니다.	/meeting-entrance/video-room
# consulting-api	미팅거절/취소	patch	미팅을 거절/취소 합니다.	/meeting-manage/cancel-reject/{choiceNo}
# consulting-api	미팅확정	patch	미팅을 확정합니다.	/meeting-manage/confirm/{choiceNo}
# consulting-api	미팅수정	patch	미팅을 수정 합니다.	/meeting-manage/request/{choiceNo}
# consulting-api	미팅 상세 조회	get	미팅 상세 정보를 조회합니다.	/meeting-manage/{choiceNo}
# consulting-api	미팅목록 조회	get	미팅목록을 조회합니다.	/meeting-manage/{userNoSelect}/meeting
# consulting-api	미팅신청	post	비즈매칭 미팅을 신청합니다.	/meeting-request
# consulting-api	스케줄정보	get	스케줄 정보를 조회합니다.	/meeting-request/schdul-info
# consulting-api	행사미팅시간 조회	get	행사미팅시간 정보를 조회합니다.	/meeting-request/schdul/{schdulNo}/{userNo}/{cnslUserNo}
# consulting-api	미팅신청정보(사용자) 조회	get	미팅 신청폼에서 사용할 로그인 사용자 정보를 조회합니다.	/meeting-request/user
# consulting-api	메세지 등록(사용자 간)	post	메세지 정보를 등록합니다.	/message
# consulting-api	계정 별 메세지 목록 조회	get	계정 별 메세지 목록을 조회합니다. (선택한 사용자와의 발/수신 목록을 조회합니다.)	/message/account/{projectCd}/{siteId}/{msgUserNo}
# consulting-api	메세지 등록(미팅 자동 발송)	post	메세지 정보(미팅 메세지 정보)를 등록합니다.	/message/meeting
# consulting-api	메세지 목록 조회	get	메세지 목록을 조회합니다.	/message/{projectCd}/{siteId}
# consulting-api	메세지 상세 조회	get	메세지 상세를 조회합니다.	/message/{projectCd}/{siteId}/{msgNo}
# consulting-api	대기리스트 갯수 조회	get	스케줄표의 미팅대기리스트 갯수 조회 합니다.	/schdul-manage/{schdulNo}/{selUserNo}/meeting-ready-count
# consulting-api	메세지 목록 조회	get	메세지 정보를 목록 조회합니다.	/tb/message
# consulting-api	메시지 등록	post	메세지 정보를 등록합니다.	/tb/message
# consulting-api	메세지 수신 목록 조회	get	메세지 수신 정보를 목록 조회합니다.	/tb/message/rcv
# consulting-api	메시지 수신 등록	post	메세지 수신 정보를 등록합니다.	/tb/message/rcv
# consulting-api	메세지 수신 단건 조회	get	메세지 수신 정보를 단건 조회합니다.	/tb/message/rcv/{rcvMsgNo}
# consulting-api	메세지 수신 삭제	delete	메세지 수신 정보를 삭제합니다.	/tb/message/rcv/{rcvMsgNo}
# consulting-api	메세지 수신 수정	patch	메세지 수신 정보를 수정합니다.	/tb/message/rcv/{rcvMsgNo}
# consulting-api	메세지 사유 목록 조회	get	메세지 사유 정보를 목록 조회합니다.	/tb/message/reason
# consulting-api	메시지 사유 등록	post	메세지 사유 정보를 등록합니다.	/tb/message/reason
# consulting-api	메세지 사유 단건 조회	get	메세지 사유 정보를 단건 조회합니다.	/tb/message/reason/{mgsRsnNo}
# consulting-api	메세지 사유 삭제	delete	메세지 사유 정보를 삭제합니다.	/tb/message/reason/{mgsRsnNo}
# consulting-api	메세지 사유 수정	patch	메세지 사유 정보를 수정합니다.	/tb/message/reason/{mgsRsnNo}
# consulting-api	메세지 단건 조회	get	메세지 정보를 단건 조회합니다.	/tb/message/{msgNo}
# consulting-api	메세지 삭제	delete	메세지 정보를 삭제합니다.	/tb/message/{msgNo}
# consulting-api	메세지 수정	patch	메세지 정보를 수정합니다.	/tb/message/{msgNo}
# consulting-api	상담 스케줄 목록 조회	get	상담 스케줄 정보를 목록 조회합니다.	/tb/schdul
# consulting-api	상담 스케줄 등록	post	상담 스케줄 정보를 등록합니다.	/tb/schdul
# consulting-api	상담 상세 스케줄 목록 조회	get	상담 상세 스케줄 정보를 목록 조회합니다.	/tb/schdul/detail
# consulting-api	상담 상세 스케줄 등록	post	상담 스케줄 정보를 등록합니다.	/tb/schdul/detail
# consulting-api	상담스케줄상세블락 목록 조회	get	상담스케줄상세블락 목록을 조회합니다.	/tb/schdul/detail/block
# consulting-api	상담스케줄 상세블락 등록	post	상담스케줄 상세블락 정보를 추가합니다.	/tb/schdul/detail/block
# consulting-api	상담스케줄상세블락이력 목록 조회	get	상담스케줄상세블락이력 목록을 조회합니다.	/tb/schdul/detail/block/hist
# consulting-api	상담스케줄상세블락 이력 등록	post	상담스케줄 상세블락 이력 정보를 추가합니다.	/tb/schdul/detail/block/hist
# consulting-api	상담스케줄 상세블락 이력 등록(기존정보 조회후)	post	상담스케줄 상세블락 이력 정보를 추가합니다.(기존정보 조회후)	/tb/schdul/detail/block/hist-after
# consulting-api	상담스케줄상세블락이력 조회	get	상담스케줄상세블락이력을 조회합니다.	/tb/schdul/detail/block/hist/{histNo}
# consulting-api	상담스케줄상세블락이력 수정	patch	상담 상세 스케줄의 블락 이력을 수정합니다.	/tb/schdul/detail/block/hist/{histNo}
# consulting-api	상담스케줄상세블락 조회	get	상담스케줄상세블락을 조회합니다.	/tb/schdul/detail/block/{userNo}/{detailNo}
# consulting-api	상담상세스케줄블락 삭제	delete	(논리적) 상담 상세 스케줄의 블락을 삭제합니다.	/tb/schdul/detail/block/{userNo}/{detailNo}
# consulting-api	상담스케줄상세블락 수정	patch	상담스케줄 상세블락 정보를 변경합니다.	/tb/schdul/detail/block/{userNo}/{detailNo}
# consulting-api	스케줄선택 목록 조회	get	스케줄선택 목록을 조회합니다.	/tb/schdul/detail/choice
# consulting-api	스케줄선택 등록	post	스케줄선택 정보를 추가합니다.	/tb/schdul/detail/choice
# consulting-api	스케줄선택이력 목록 조회	get	스케줄선택이력 목록을 조회합니다.	/tb/schdul/detail/choice/hist
# consulting-api	스케줄선택이력 등록	post	스케줄선택이력 정보를 추가합니다.	/tb/schdul/detail/choice/hist
# consulting-api	스케줄선택이력 등록 (기존정보 조회후)	post	스케줄선택이력 정보 를 추가합니다. (기존정보 조회후)	/tb/schdul/detail/choice/hist-after
# consulting-api	스케줄선택이력 조회	get	스케줄선택이력을 조회합니다.	/tb/schdul/detail/choice/hist/{histNo}
# consulting-api	스케줄선택이력 수정	patch	스케줄선택이력 정보를 변경합니다.	/tb/schdul/detail/choice/hist/{histNo}
# consulting-api	스케줄선택 조회	get	스케줄선택을 조회합니다.	/tb/schdul/detail/choice/{choiceNo}
# consulting-api	스케줄선택 삭제	delete	(논리적) 스케줄선택을 삭제합니다.	/tb/schdul/detail/choice/{choiceNo}
# consulting-api	스케줄선택 수정	patch	스케줄선택 정보를 변경합니다.	/tb/schdul/detail/choice/{choiceNo}
# consulting-api	상담 상세 스케줄 단건 조회	get	상담 상세 스케줄 정보를 단건 조회합니다.	/tb/schdul/detail/{detailNo}
# consulting-api	상담 상세 스케줄 삭제	delete	상담 스케줄 정보를 삭제합니다.	/tb/schdul/detail/{detailNo}
# consulting-api	상담 상세 스케줄 수정	patch	상담 스케줄 정보를 수정합니다.	/tb/schdul/detail/{detailNo}
# consulting-api	버튼 노출 여부 조회	post	버튼 노출 여부 조회	/tb/schdul/displayButton
# consulting-api	상담 스케줄 알림 설정 목록 조회	get	상담 스케줄 알림 설정 정보를 목록 조회합니다.	/tb/schdul/notice/set
# consulting-api	상담 스케줄 알림 설정 등록	post	상담 스케줄 알림 설정 정보를 등록합니다.	/tb/schdul/notice/set
# consulting-api	상담 스케줄 알림 설정 단건 조회	get	상담 스케줄 알림 설정 정보를 단건 조회합니다.	/tb/schdul/notice/set/{setNo}
# consulting-api	상담 스케줄 알림 설정 삭제	delete	상담 스케줄 알림 설정 정보를 삭제합니다.	/tb/schdul/notice/set/{setNo}
# consulting-api	상담 스케줄 알림 설정 수정	patch	상담 스케줄 알림 설정 정보를 수정합니다.	/tb/schdul/notice/set/{setNo}
# consulting-api	상담 스케줄 단건 조회	get	상담 스케줄 정보를 단건 조회합니다.	/tb/schdul/{schdulNo}
# consulting-api	상담 스케줄 삭제	delete	상담 스케줄 정보를 삭제합니다.	/tb/schdul/{schdulNo}
# consulting-api	상담 스케줄 수정	patch	상담 스케줄 정보를 수정합니다.	/tb/schdul/{schdulNo}
# consulting-api	화상회의 목록 조회	get	화상회의 목록을 조회합니다.	/tb/video
# consulting-api	화상회의 등록	post	화상회의 정보를 추가합니다.	/tb/video
# consulting-api	화상회의상세 목록 조회	get	화상회의상세 목록을 조회합니다.	/tb/video/detail
# consulting-api	화상회의상세 등록	post	화상회의상세 정보를 추가합니다.	/tb/video/detail
# consulting-api	화상회의상세 조회	get	화상회의상세을 조회합니다.	/tb/video/detail/{videoDetailNo}
# consulting-api	화상회의상세 삭제	delete	(논리적) 화상회의상세 정보를 삭제합니다.	/tb/video/detail/{videoDetailNo}
# consulting-api	화상회의상세 수정	patch	화상회의상세 정보를 수정합니다.	/tb/video/detail/{videoDetailNo}
# consulting-api	화상회의 조회	get	화상회의를 조회합니다.	/tb/video/{videoNo}
# consulting-api	화상회의 삭제	delete	(논리적) 화상회의 정보를 삭제합니다.	/tb/video/{videoNo}
# consulting-api	화상회의 수정	patch	화상회의 정보를 수정합니다.	/tb/video/{videoNo}
# consulting-api	zoom 목록 조회	get	zoom 목록을 조회합니다.	/tb/zoom
# consulting-api	zoom 등록	post	zoom 정보를 추가합니다.	/tb/zoom
# consulting-api	zoom 상세 목록 조회	get	zoom 상세 목록을 조회합니다.	/tb/zoom/detail
# consulting-api	zoom 상세 등록	post	zoom 상세 정보를 추가합니다.	/tb/zoom/detail
# consulting-api	zoom 상세 조회	get	zoom 상세를 조회합니다.	/tb/zoom/detail/{zoomDetailNo}
# consulting-api	zoom 상세 수정	patch	zoom 상세 정보를 수정합니다.	/tb/zoom/detail/{zoomDetailNo}
# consulting-api	zoom 목록 조회	get	zoom 목록을 조회합니다.	/tb/zoom/{zoomNo}
# consulting-api	zoom 수정	patch	zoom 정보를 수정합니다.	/tb/zoom/{zoomNo}
# contents-api	세션 분류별, 기업명으로 목록 조회	get	세션 분류 및 기업명으로 조회	/service/session
# contents-api	tbc_세션 목록 조회(검색조건 : tbc_session, tbc_session_detail, tbc_session_company)	get	tbc_세션 목록 조회(검색조건 : tbc_session, tbc_session_detail, tbc_session_company)	/session
# contents-api	tbc_세션 등록(tbc_session, tbc_session_detail, tbc_session_company)	post	tbc_세션 등록(tbc_session, tbc_session_detail, tbc_session_company)	/session
# contents-api	세션 댓글 수정	post	세션 댓글 수정	/session-comment/modify
# contents-api	세션 댓글 등록	post	세션 댓글 등록	/session-comment/register
# contents-api	세션콘텐츠 목록 조회(tbc_session_ctnt, tbc_session_ctnt_detail)	get	세션콘텐츠 목록 조회	/session-ctnt
# contents-api	tbc_세션콘텐츠 등록(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	post	tbc_세션콘텐츠 등록(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	/session-ctnt
# contents-api	tbc_세션콘텐츠매핑 목록 조회(검색조건 : tbc_session_ctnt_mapp, tbc_session_ctnt, tbc_session_ctnt_detail)	get	tbc_세션콘텐츠매핑 목록 조회(검색조건 : tbc_session_ctnt_mapp, tbc_session_ctnt, tbc_session_ctnt_detail)	/session-ctnt-mapp
# contents-api	tbc_세션콘텐츠매핑 정렬순서 수정	patch	tbc_세션콘텐츠매핑 정렬순서 수정합니다.	/session-ctnt-mapp/modify-ord-list
# contents-api	이전, 다음 세션 콘텐츠 조회	post	세션목록(로직)을 조회합니다.	/session-ctnt/pre-next
# contents-api	세션콘텐츠 상세 조회(tbc_session_ctnt, tbc_session_ctnt_detail)	get	세션콘텐츠 목록 조회	/session-ctnt/{ssnCtntNo}
# contents-api	tbc_세션콘텐츠 삭제(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	delete	tbc_세션콘텐츠 삭제(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	/session-ctnt/{ssnCtntNo}
# contents-api	tbc_세션콘텐츠 수정(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	patch	tbc_세션콘텐츠 수정(tbc_session_ctnt, tbc_session_ctnt_detail, tbc_session_ctnt_mapp)	/session-ctnt/{ssnCtntNo}
# contents-api	세션 신청 목록 조회	post	세션 신청 목록을 조회합니다.	/session-mapp
# contents-api	세션 수정 (단건)	post	세션 신청을 합니다.	/session-mapp/modify
# contents-api	세션 수정 (멀티)	post	세션 신청을 합니다.	/session-mapp/multi-modify
# contents-api	세션 신청 및 취소	post	세션 신청 및 취소를 합니다.	/session-mapp/register
# contents-api	tbc_세션 및 콘텐츠 통합 등록	post	tbc_세션 및 콘텐츠 통합 등록	/session-total
# contents-api	이전, 다음 세션 조회	post	세션목록(로직)을 조회합니다.	/session/pre-next
# contents-api	tbc_세션 삭제(tbc_session, tbc_session_detail, tbc_session_company, tbc_session_ctnt_mapp)	delete	tbc_세션 삭제(tbc_session, tbc_session_detail, tbc_session_company, tbc_session_ctnt_mapp)	/session/{ssnId}
# contents-api	tbc_세션 수정(tbc_session, tbc_session_detail, tbc_session_company)	patch	tbc_세션 수정(tbc_session, tbc_session_detail, tbc_session_company)	/session/{ssnId}
# contents-api	TB 세션 목록 조회	get	TB 세션 목록 조회	/tb/session
# contents-api	TB 세션 등록	post	TB 세션 등록	/tb/session
# contents-api	TB 실시간반응 목록 조회	get	TB 실시간반응 목록 조회	/tb/session-comment
# contents-api	TB 실시간반응 단건 조회	get	TB 실시간반응 단건 조회	/tb/session-comment/{cmtNo}
# contents-api	TB 실시간반응 삭제	delete	TB 실시간반응 삭제	/tb/session-comment/{cmtNo}
# contents-api	TB 세션기업 목록 조회	get	TB 세션기업 목록 조회	/tb/session-company
# contents-api	TB 세션기업 등록	post	TB 세션기업 등록	/tb/session-company
# contents-api	TB 세션기업 단건 조회	get	TB 세션기업 단건 조회	/tb/session-company/{ssnCompanyNo}
# contents-api	TB 세션기업 삭제	delete	TB 세션기업 삭제	/tb/session-company/{ssnCompanyNo}
# contents-api	TB 세션기업 수정	patch	TB 세션기업 수정	/tb/session-company/{ssnCompanyNo}
# contents-api	TB 세션콘텐츠 목록 조회	get	TB 세션콘텐츠 목록 조회	/tb/session-ctnt
# contents-api	TB 세션콘텐츠 등록	post	TB 세션콘텐츠 등록	/tb/session-ctnt
# contents-api	TB 세션콘텐츠매핑 목록 조회	get	TB 세션콘텐츠매핑 목록 조회	/tb/session-ctnt-mapp
# contents-api	TB 세션콘텐츠매핑 등록	post	TB 세션콘텐츠매핑 등록	/tb/session-ctnt-mapp
# contents-api	TB 세션콘텐츠매핑 단건 조회	get	TB 세션콘텐츠매핑 단건 조회	/tb/session-ctnt-mapp/{ssnCtntMappNo}
# contents-api	TB 세션콘텐츠매핑 삭제	delete	TB 세션콘텐츠매핑 삭제	/tb/session-ctnt-mapp/{ssnCtntMappNo}
# contents-api	TB 세션콘텐츠매핑 수정	patch	TB 세션콘텐츠매핑 수정	/tb/session-ctnt-mapp/{ssnCtntMappNo}
# contents-api	TB 세션콘텐츠상세 목록 조회	get	TB 세션콘텐츠상세 목록 조회	/tb/session-ctnt/detail
# contents-api	TB 세션콘텐츠상세 등록	post	TB 세션콘텐츠상세 등록	/tb/session-ctnt/detail
# contents-api	TB 세션콘텐츠상세 단건 조회	get	TB 세션콘텐츠상세 단건 조회	/tb/session-ctnt/detail/{ssnCtntNo}/{langCd}
# contents-api	 TB 세션콘텐츠상세 삭제	delete	TB 세션콘텐츠상세 삭제	/tb/session-ctnt/detail/{ssnCtntNo}/{langCd}
# contents-api	TB 세션콘텐츠상세 수정	patch	TB 세션콘텐츠상세 수정	/tb/session-ctnt/detail/{ssnCtntNo}/{langCd}
# contents-api	TB 세션콘텐츠 단건 조회	get	TB 세션콘텐츠 단건 조회	/tb/session-ctnt/{ssnCtntNo}
# contents-api	TB 세션콘텐츠 삭제	delete	TB 세션콘텐츠 삭제	/tb/session-ctnt/{ssnCtntNo}
# contents-api	TB 세션콘텐츠 수정	patch	TB 세션콘텐츠 수정	/tb/session-ctnt/{ssnCtntNo}
# contents-api	TB 세션view 목록 조회	get	TB 세션view 목록 조회	/tb/session-view
# contents-api	TB 세션view 등록	post	TB 세션view 등록	/tb/session-view
# contents-api	TB 세션view 단건 조회	get	TB 세션view 단건 조회	/tb/session-view/{viewNo}
# contents-api	TB 세션view 삭제	delete	TB 세션view 삭제	/tb/session-view/{viewNo}
# contents-api	TB 세션view 수정	patch	TB 세션view 수정	/tb/session-view/{viewNo}
# contents-api	TB 세션상세 목록 조회	get	TB 세션상세 목록 조회	/tb/session/detail
# contents-api	TB 세션상세 등록	post	TB 세션상세 등록	/tb/session/detail
# contents-api	TB 세션상세 단건 조회	get	TB 세션상세 단건 조회	/tb/session/detail/{ssnId}/{langCd}
# contents-api	TB 세션상세 삭제	delete	TB 세션상세 삭제	/tb/session/detail/{ssnId}/{langCd}
# contents-api	TB 세션상세 수정	patch	TB 세션상세 수정	/tb/session/detail/{ssnId}/{langCd}
# contents-api	TB 세션 단건 조회	get	TB 세션 단건 조회	/tb/session/{ssnId}
# contents-api	TB 세션 삭제	delete	TB 세션 삭제	/tb/session/{ssnId}
# contents-api	TB 세션 수정	patch	TB 세션 수정	/tb/session/{ssnId}
# counseling-api	상담 목록 조회	get	상담 목록을 조회합니다.	/counseling
# counseling-api	행사만들기 상담 등록	post	행사만들기 상담을 등록합니다..	/counseling
# counseling-api	행사만들기 상담 수정	patch	행사만들기 상담 수정	/counseling
# counseling-api	상담댓글 추가	post	상담댓글을 추가합니다.	/counseling/comment
# counseling-api	상담댓글 삭제	delete	댓글을 삭제합니다.	/counseling/comment/{commentNo}
# counseling-api	담당자 지정 및 취소	patch	담당자를 지정 및 취소 합니다.	/counseling/manager
# counseling-api	상담내역 조회	get	상담을 조회합니다.	/counseling/{postNo}
# counseling-api	행사만들기 상담 삭제	delete	행사만들기 상담 삭제	/counseling/{postNo}
# counseling-api	상담댓글 목록 조회	get	상담댓글 목록을 조회합니다.	/counseling/{postNo}/comment
# coupon-api	쿠폰-상품 매핑 수정	patch		/admin/coupon/goods
# coupon-api	쿠폰-상품 매핑 등록	post		/admin/coupon/goods/register
# coupon-api	쿠폰-상품 매핑 삭제(논리)	delete		/admin/coupon/goods/{couponGoodsNo}
# coupon-api	쿠폰 목록 조회	post		/coupon
# coupon-api	쿠폰 수정	patch		/coupon
# coupon-api	쿠폰 적용하기	post		/coupon/apply
# coupon-api	쿠폰 번호 중복 확인	post		/coupon/duplicateChk
# coupon-api	쿠폰-상품 매핑 목록 조회	post		/coupon/goods
# coupon-api	쿠폰 번호 이용하여 쿠폰-상품 매핑 목록 조회	post		/coupon/goods/mapping
# coupon-api	쿠폰 번호 발급	post		/coupon/issuance
# coupon-api	쿠폰매핑 조회	post		/coupon/mapp
# coupon-api	사용자 쿠폰등록	post		/coupon/mapp/register
# coupon-api	쿠폰-사용자 매핑 삭제(논리)	delete		/coupon/mapp/{couponMappNo}
# coupon-api	쿠폰 등록	post		/coupon/register
# coupon-api	쿠폰 사용하기	post		/coupon/useCoupon
# coupon-api	쿠폰 삭제(논리)	delete		/coupon/{couponNo}
# goods-api	서버 작동 여부 확인	get		/
# goods-api	로그인한 사용자의 정보 확인 api	get	로그인한 사용자의 간단한 정보를 볼 수 있다	/example/me
# goods-api	현재 날짜와 시간을 반환	get	v년도-시간값 반환해준다	/example/tag
# goods-api	v2) 관리자 권한 토큰 발행 api	post	발행받은 토큰 값을 상단 Authorize 버튼 누르고 입력 후 인증 받으세요.	/example/v2/admin-token
# goods-api	v2) 유저 권한 토큰 발행 api	post	발행받은 토큰 값을 상단 Authorize 버튼 누르고 입력 후 인증 받으세요.	/example/v2/user-token
# inquiry-api	서버 작동 여부 확인	get		/
# inquiry-api	로그인한 사용자의 정보 확인 api	get	로그인한 사용자의 간단한 정보를 볼 수 있다	/example/me
# inquiry-api	현재 날짜와 시간을 반환	get	v년도-시간값 반환해준다	/example/tag
# inquiry-api	v2) 관리자 권한 토큰 발행 api	post	발행받은 토큰 값을 상단 Authorize 버튼 누르고 입력 후 인증 받으세요.	/example/v2/admin-token
# inquiry-api	v2) 유저 권한 토큰 발행 api	post	발행받은 토큰 값을 상단 Authorize 버튼 누르고 입력 후 인증 받으세요.	/example/v2/user-token
# logging-api	클릭로그 등록	post	클릭로그 정보를 추가합니다.	/log/addClickLog
# logging-api	에러로그 등록	post	에러로그 정보를 추가합니다.	/log/addErrorLog
# logging-api	로그인이력 등록	post	로그인이력 정보를 추가합니다.	/log/addLoginHistoryLog
# logging-api	영상시청 등록	post	영상시청 정보를 추가합니다.	/log/addMovieLog
# logging-api	영상시청로그 등록	post	영상시청로그 정보를 추가합니다.	/log/addMovietimeLog
# logging-api	사이트접속로그 등록	post	사이트접속로그 정보를 추가합니다.	/log/addSiteLog
# logging-api	사이트로그메뉴명 등록	post	사이트로그메뉴명 정보를 추가합니다.	/log/addSiteLogMenuname
# logging-api	유저로그시간 등록	post	유저로그시간 정보를 추가합니다.	/log/addUserLog
# logging-api	프로필방문로그 등록	post	프로필방문로그 정보를 추가합니다.	/log/addVisitProfileLog
# logging-api	클릭로그 조회	post	클릭로그 목록을 조회합니다.	/log/getClickLogList
# logging-api	에러로그 조회	post	에러로그 목록을 조회합니다.	/log/getErrorLogList
# logging-api	로그인이력 조회	post	로그인이력 목록을 조회합니다.	/log/getLoginHistoryLogList
# logging-api	로그아웃이력 조회	post	로그아웃이력 목록을 조회합니다.	/log/getLogoutHistoryLogList
# logging-api	영상시청 조회	post	영상시청 목록을 조회합니다.	/log/getMovieLogList
# logging-api	영상시청로그 조회	post	영상시청로그 목록을 조회합니다.	/log/getMovietimeLogList
# logging-api	사이트접속로그 조회	post	사이트접속로그 목록을 조회합니다.	/log/getSiteLogList
# logging-api	사이트로그메뉴명 조회	post	사이트로그메뉴명 목록을 조회합니다.	/log/getSiteLogMenunameList
# logging-api	유저로그시간 조회	post	유저로그시간 목록을 조회합니다.	/log/getUserLogList
# logging-api	프로필방문로그 조회	post	프로필방문로그 목록을 조회합니다.	/log/getVisitProfileLogList
# logging-api	로그인 내역 조회	post	로그인 내역 목록을 조회합니다.	/log/read/v2/login-history
# logging-api	사이트로그메뉴명 수정	post	사이트로그메뉴명 정보를 변경합니다.	/log/setSiteLogMenuname
# logging-api	로그인 내역 등록	post	로그인 내역 정보를 추가합니다.	/log/v2/login-history
# logging-api	클릭 로그 등록	post	클릭 로그 정보를 추가합니다. (banner-b / sponContets-sp / companyContents-c )	/logging/regist-click-log
# logging-api	Download 로그 등록	post	Download 로그 정보를 추가합니다.	/logging/regist-download-log
# logging-api	영상 로그 등록	post	영상 로그 정보를 추가합니다. (sponContets-sp / companyContents-c / session-s / sessionContents-sc)	/logging/regist-movie-log
# logging-api	세션 시청 로그 등록	post	세션 시청 로그 정보를 추가합니다.(session-s)	/logging/regist-movie-sessiontime-log
# logging-api	영상 시청 로그 등록	post	영상 시청 로그 정보를 추가합니다.(sponContets-sp / companyContents-c / sessionContents-sc)	/logging/regist-movietime-log
# logging-api	사이트 로그 등록	post	사이트접속로그 정보를 추가합니다.	/logging/regist-site-log
# logging-api	SNS공유 로그 등록	post	SNS공유 로그 정보를 추가합니다.	/logging/regist-sns-share-log
# logging-api	기업 방문 로그 등록	post	기업 방문 로그 정보를 추가합니다.	/logging/regist-visit-profile-log
# login2-api	비밀번호 수정	post	로그인한 상태에서 비밀번호를 수정하면 임시비밀번호 상태를 업데이트하고 새로운 비밀번호로 업데이트한다	/auth/admin/password
# login2-api	가입 인증 - 이메일	post	랜덤키가 담긴 가입 인증을 확인하는 이메일을 전송한다 - 유효 시간 3분	/auth/email
# login2-api	아이디 찾기 기능	post	사용자가 이름, 번호를 입력하면 아이디 목록을 반환한다	/auth/id-list
# login2-api	통합 로그인(토큰생성) - JSON Web Token 반환	post	인증후 토큰을 생성하여 반환한다	/auth/local
# login2-api	내 정보 api	get	내 정보 api	/auth/me
# login2-api	비밀번호 수정	post	로그인한 상태에서 비밀번호를 수정하면 임시비밀번호 상태를 업데이트하고 새로운 비밀번호로 업데이트한다	/auth/password
# login2-api	비밀번호 찾기 기능 - 이메일	post	사용자가 아이디를 입력하면 조회하여 유효한 아이디라면 임시비밀번호 생성 후 메일로 전송한다	/auth/password/email
# login2-api	소셜 유저 존재 확인	get	소셜 유저가 DB에 있는지 확인하는 api	/auth/social
# login2-api	소셜 로그인 - JSON Web Token 반환	post	네이버, 구글, 카카오등 소셜 유저의 인증토큰생성하여 반환한다	/auth/social
# login2-api	/auth/social-decode	post		/auth/social-decode
# login2-api	인증	get	발급받은 번호로 인증한다	/auth/{verifyKey}
# mailing-api	/copy/sender/{projectCd}/{siteId}	post		/copy/sender/{projectCd}/{siteId}
# mailing-api	/copy/template/{projectCd}/{siteId}	post		/copy/template/{projectCd}/{siteId}
# mailing-api	(다중)즉시발송 ==> 발송하며 배치, 예약발송 ==> 저장 후 배치에서 발송	post		/mailsend/multi
# mailing-api	(재전송) 즉시발송	post		/mailsend/resend
# mailing-api	단일 발송 (즉시, 배치, 예약)	post		/mailsend/single
# mailing-api	예약발송 대기 메일 즉시 발송	post		/mailsend/single/reserved-mail
# mailing-api	단일 발송 (즉시) : recipientNo에게 발송	post		/mailsend/single/{recipientNo}
# mailing-api	발송 이력 목록	get		/tb/history
# mailing-api	발송계정 상세정보	get		/tb/history/{sendHistSeq}
# mailing-api	발송대기내역	get		/tb/mailsend
# mailing-api	발송대기 삭제	delete		/tb/mailsend
# mailing-api	발송대기 취소여부 수정	patch		/tb/mailsend
# mailing-api	발송대기 상세정보	get		/tb/mailsend/{sendSeq}
# mailing-api	발송계정 목록	get		/tb/sender
# mailing-api	발송계정 수정	put		/tb/sender
# mailing-api	발송계정 등록	post		/tb/sender
# mailing-api	발송계정 사용여부 수정	patch		/tb/sender
# mailing-api	발송계정 상세정보	get		/tb/sender/{senderSeq}
# mailing-api	발송계정 삭제(물리)	delete		/tb/sender/{senderSeq}
# mailing-api	템플릿 목록	get		/tb/template
# mailing-api	템플릿 등록	post		/tb/template
# mailing-api	템플릿 사용 여부 수정	patch		/tb/template
# mailing-api	템플릿 상세정보조회	get		/tb/template/detail/{tmplDetailSeq}
# mailing-api	템플릿 디테일 수정	put		/tb/template/detail/{tmplDetailSeq}
# mailing-api	템플릿 상세정보 삭제	delete		/tb/template/detail/{tmplDetailSeq}
# mailing-api	템플릿 상세정보조회(관리)	get		/tb/template/{tmplSeq}
# mailing-api	템플릿 수정	put		/tb/template/{tmplSeq}
# mailing-api	템플릿 상세정보 입력	post		/template/detail
# mailing-api	템플릿 키 조회	get	템플릿 키를 조회한다 (projectCd, siteId, emailKeyNo, templateDetailSeq, langCd)	/template/key
# mailing-api	템플릿 키 수정	put		/template/key
# mailing-api	템플릿 키 등록	post		/template/key
# mailing-api	언어코드에 따른 키 정보	get	언어코드에 따른 키 정보	/template/keyInfo
# mailing-api	템플릿 키 여러개 등록	post		/template/keys/{projectCd}/{siteId}/{tmplDetailSeq}/{langCd}
# mailing-api	템플릿 메일 전송 전 미리보기	get		/template/preview
# mavatar-api	사용자정보로 아바타 조회	get	사용자정보로 아바타 조회	/mavatar/{projectCd}/{siteId}/{userNo}
# mavatar-api	TB Avatar 등록	post	TB Avatar 등록	/tb/avatar
# mavatar-api	TB Avatar 수정	patch	TB Avatar 수정	/tb/avatar/{avatarNo}
# mavatar-api	TB Avatar 목록 조회	get	TB Avatar 목록 조회	/tb/mavatar
# mavatar-api	TB Avatar 단건 조회	get	TB Avatar 단건 조회	/tb/mavatar/{avatarNo}
# mavatar-api	TB Avatar 삭제	delete	TB Avatar 삭제	/tb/mavatar/{avatarNo}
# mbody-api	몸통 목록 조회	post	몸통 정보를 목록 조회합니다.	/tb/mbody
# mbody-api	몸통 등록	post	몸통 정보를 등록합니다.	/tb/mbody/regist
# mbody-api	몸통 단건 조회	get	몸통 정보를 단건 조회합니다.	/tb/mbody/{bodyNo}
# mbody-api	몸통 삭제	delete	몸통 정보를 삭제합니다.	/tb/mbody/{bodyNo}
# mbody-api	몸통 수정	patch	몸통 정보를 수정합니다.	/tb/mbody/{bodyNo}
# mcloth-api	의상 목록 조회	post	의상 정보를 목록 조회합니다.	/tb/mcloth
# mcloth-api	의상 등록	post	의상 정보를 등록합니다.	/tb/mcloth/regist
# mcloth-api	의상 단건 조회	get	의상 정보를 단건 조회합니다.	/tb/mcloth/{clothNo}
# mcloth-api	의상 삭제	delete	의상 정보를 삭제합니다.	/tb/mcloth/{clothNo}
# mcloth-api	의상 수정	patch	의상 정보를 수정합니다.	/tb/mcloth/{clothNo}
# mface-api	얼굴 목록 조회	post	얼굴 정보를 목록 조회합니다.	/tb/mface
# mface-api	얼굴 등록	post	얼굴 정보를 등록합니다.	/tb/mface/regist
# mface-api	얼굴 단건 조회	get	얼굴 정보를 단건 조회합니다.	/tb/mface/{faceNo}
# mface-api	얼굴 삭제	delete	얼굴 정보를 삭제합니다.	/tb/mface/{faceNo}
# mface-api	얼굴 수정	patch	얼굴 정보를 수정합니다.	/tb/mface/{faceNo}
# mhair-api	머리 목록 조회	post	머리 정보를 목록 조회합니다.	/tb/mhair
# mhair-api	머리 등록	post	머리 정보를 등록합니다.	/tb/mhair/regist
# mhair-api	머리 단건 조회	get	머리 정보를 단건 조회합니다.	/tb/mhair/{hairNo}
# mhair-api	머리 삭제	delete	머리 정보를 삭제합니다.	/tb/mhair/{hairNo}
# mhair-api	머리 수정	patch	머리 정보를 수정합니다.	/tb/mhair/{hairNo}
# micecontents-api	기업소개콘텐츠 등록(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	post	기업소개콘텐츠 등록합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt
# micecontents-api	기업소개콘텐츠 상세 조회(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	get	기업소개콘텐츠 상세 조회합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt/detail/{projectCd}/{siteId}/{companyCtntNo}
# micecontents-api	기업소개콘텐츠 정렬순서 수정	patch	기업소개콘텐츠 정렬순서 수정합니다.	/company-ctnt/modify-disp-order-list
# micecontents-api	기업소개콘텐츠 삭제(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	delete	기업소개콘텐츠 삭제합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt/{companyCtntNo}
# micecontents-api	기업소개콘텐츠 수정(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	patch	기업소개콘텐츠 수정합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt/{companyCtntNo}
# micecontents-api	검색 기업소개콘텐츠 리스트 조회(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	get	검색 기업소개콘텐츠 리스트 조회합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt/{projectCd}/{siteId}
# micecontents-api	회사별 기업소개콘텐츠 리스트 조회(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	get	회사별 기업소개콘텐츠 리스트 조회합니다.(tb_company_ctnt, tb_company_ctnt_detail, tb_company_ctnt_detail_sub)	/company-ctnt/{projectCd}/{siteId}/{companyNo}
# micecontents-api	TB 기업콘텐츠 목록 조회	get	TB 기업콘텐츠 목록 조회	/tb/company-ctnt
# micecontents-api	TB 기업콘텐츠 등록	post	TB 기업콘텐츠 등록	/tb/company-ctnt
# micecontents-api	TB 기업콘텐츠상세 목록 조회	get	TB 기업콘텐츠상세 목록 조회	/tb/company-ctnt/detail
# micecontents-api	TB 기업콘텐츠상세 등록	post	TB 기업콘텐츠상세 등록	/tb/company-ctnt/detail
# micecontents-api	TB 기업콘텐츠서브 목록 조회	get	TB 기업콘텐츠서브 목록 조회	/tb/company-ctnt/detail-sub
# micecontents-api	TB 기업콘텐츠서브 등록	post	TB 기업콘텐츠서브 등록	/tb/company-ctnt/detail-sub
# micecontents-api	TB 기업콘텐츠서브 단건 조회	get	TB 기업콘텐츠서브 단건 조회	/tb/company-ctnt/detail-sub/{companyCtntDetailSubSeq}
# micecontents-api	TB 기업콘텐츠서브 삭제	delete	TB 기업콘텐츠서브 Detail 삭제	/tb/company-ctnt/detail-sub/{companyCtntDetailSubSeq}
# micecontents-api	TB 기업콘텐츠서브 수정	patch	TB 기업콘텐츠서브 수정	/tb/company-ctnt/detail-sub/{companyCtntDetailSubSeq}
# micecontents-api	TB 기업콘텐츠상세 단건 조회	get	TB 기업콘텐츠상세 단건 조회	/tb/company-ctnt/detail/{companyCtntNo}/{langCd}
# micecontents-api	TB 기업콘텐츠상세 삭제	delete	TB 기업콘텐츠상세 삭제	/tb/company-ctnt/detail/{companyCtntNo}/{langCd}
# micecontents-api	TB 기업콘텐츠상세 수정	patch	TB 기업콘텐츠상세 수정	/tb/company-ctnt/detail/{companyCtntNo}/{langCd}
# micecontents-api	TB 기업콘텐츠 단건 조회	get	TB 기업콘텐츠 단건 조회	/tb/company-ctnt/{companyCtntNo}
# micecontents-api	TB 기업콘텐츠 삭제	delete	TB 기업콘텐츠 삭제	/tb/company-ctnt/{companyCtntNo}
# micecontents-api	TB 기업콘텐츠 수정	patch	TB 기업콘텐츠 수정	/tb/company-ctnt/{companyCtntNo}
# mregion-api	지역 목록 조회	post	지역 정보를 목록 조회합니다.	/tb/mregion
# mregion-api	지역 등록	post	지역 정보를 등록합니다.	/tb/mregion/regist
# mregion-api	지역 단건 조회	get	지역 정보를 단건 조회합니다.	/tb/mregion/{regionNo}
# mregion-api	지역 수정	patch	지역 정보를 수정합니다.	/tb/mregion/{regionNo}
# mregion-api	지역 삭제	delete	지역 정보를 삭제합니다.	/tb/region/{regionNo}
# mshoes-api	신발 목록 조회	post	신발 정보를 목록 조회합니다.	/tb/mshoes
# mshoes-api	신발 등록	post	신발 정보를 등록합니다.	/tb/mshoes/regist
# mshoes-api	신발 단건 조회	get	신발 정보를 단건 조회합니다.	/tb/mshoes/{shoseNo}
# mshoes-api	신발 삭제	delete	신발 정보를 삭제합니다.	/tb/mshoes/{shoseNo}
# mshoes-api	신발 수정	patch	신발 정보를 수정합니다.	/tb/mshoes/{shoseNo}
# mypage-api	즐겨찾기 등록	post	즐겨찾기 정보를 등록합니다.	/mypage/favorites
# mypage-api	홍보콘텐츠 즐겨찾기 목록 조회	get	홍보콘텐츠 즐겨찾기 목록을 조회합니다.	/mypage/favorites/company-ctnt/{projectCd}/{siteId}
# mypage-api	기업 즐겨찾기 목록 조회	get	기업 즐겨찾기 목록을 조회합니다.	/mypage/favorites/company/{projectCd}/{siteId}
# mypage-api	세션 콘텐츠 즐겨찾기 목록 조회	get	세션 콘텐츠 즐겨찾기 목록을 조회합니다.	/mypage/favorites/session-ctnt/{projectCd}/{siteId}
# mypage-api	세션 즐겨찾기 목록 조회	get	세션 즐겨찾기 목록을 조회합니다.	/mypage/favorites/session/{projectCd}/{siteId}
# mypage-api	즐겨찾기 삭제	delete	즐겨찾기 정보를 삭제합니다.	/mypage/favorites/{favNo}
# mypage-api	즐겨찾기 목록 조회	get	즐겨찾기 목록을 조회합니다.	/mypage/favorites/{projectCd}/{siteId}
# mypage-api	스케줄 등록	post	스케줄 등록합니다.	/mypage/schedule
# mypage-api	행사날짜 리스트 조회	get	행사날짜 리스트 조회	/mypage/schedule/event-date/{projectCd}/{siteId}
# mypage-api	스케줄(세션) 리스트 조회	get	스케줄(세션) 리스트 조회합니다.	/mypage/schedule/session/{projectCd}/{siteId}
# mypage-api	스케줄(확정된 미팅, tb_site_schdul(세션)) 리스트 조회	get	스케줄(확정된 미팅, tb_site_schdul(세션)) 리스트 조회	/mypage/schedule/{projectCd}/{siteId}
# mypage-api	스케줄 삭제	delete	스케줄 삭제합니다.	/mypage/schedule/{schdulNo}
# order-api	o2meet franchisee 조회	post		/o2meetFranchisee
# order-api	주문 목록	post		/order
# order-api	주문 수정	post		/order/modify
# order-api	주문 등록	post		/order/register
# order-api	주문 상세 조회	get		/order/{id}
# order-api	주문 상품 목록	post		/orderGoods
# order-api	주문 상품 수정	post		/orderGoods/modify
# order-api	주문 상품 등록	post		/orderGoods/register
# order-api	주문 상세 조회	get		/orderGoods/{id}
# order-api	주문 아이템 논리적 삭제	post		/ordersItems/delete
# order-api	주문 아이템 등록	post		/ordersItems/insert
# order-api	주문 아이템 목록	post		/ordersItems/list
# order-api	주문 아이템 상세 조회	get		/ordersItems/{id}
# order-api	주문 옵션 논리적 삭제	post		/ordersOptions/delete
# order-api	주문 옵션 등록	post		/ordersOptions/insert
# order-api	주문 옵션 목록	post		/ordersOptions/list
# order-api	주문 옵션 수정	post		/ordersOptions/modify
# order-api	주문 옵션 상세 조회	get		/ordersOptions/{id}
# order-api	주문 프로그램 논리적 삭제	post		/ordersPrograms/delete
# order-api	주문 프로그램 등록	post		/ordersPrograms/insert
# order-api	주문 옵션 목록	post		/ordersPrograms/list
# order-api	주문 프로그램 수정	post		/ordersPrograms/modify
# order-api	주문 프로그램 상세 조회	get		/ordersPrograms/{id}
# order-api	해당 행사 결제 방법 조회	post		/paymentMethod/project
# popup-api	알림창 등록	post	알림창 정보를 등록합니다.	/notification
# popup-api	알림창 삭제	delete	알림창 정보를 삭제합니다. Master 정보와 Detail 정보가 함께 삭제됩니다.	/notification/{notificationSeq}
# popup-api	알림창 수정	patch	알림창 정보를 수정합니다.	/notification/{notificationSeq}
# popup-api	알림창 목록 조회	get	알림창 목록을 조회합니다.	/notification/{projectCd}/{siteId}
# popup-api	알림창 상세 조회	get	알림창 상세 정보를 조회합니다.	/notification/{projectCd}/{siteId}/{notificationSeq}
# popup-api	팝업 등록	post	팝업 정보를 등록합니다.	/popup
# popup-api	팝업 편성표 조회	get	팝업 편성표룰 조회합니다.	/popup/schedule/{projectCd}/{siteId}
# popup-api	팝업 삭제	delete	팝업 정보를 삭제합니다. Master 정보와 Detail 정보가 함께 삭제됩니다.	/popup/{popupSeq}
# popup-api	팝업 수정	patch	팝업 정보를 수정합니다.	/popup/{popupSeq}
# popup-api	팝업 목록 조회	get	팝업 목록을 조회합니다.	/popup/{projectCd}/{siteId}
# popup-api	팝업 상세 조회	get	팝업 상세 정보를 조회합니다.	/popup/{projectCd}/{siteId}/{popupSeq}
# popup-api	알림창 마스터(Master) 목록 조회	get	알림창 마스터 정보를 목록 조회합니다.	/tb/notification
# popup-api	알림 마스터(Master) 등록	post	알림 마스터(Master) 정보 등록합니다.	/tb/notification
# popup-api	알림창 상세(Detail) 목록 조회	get	알림 상세 정보를 목록 조회합니다.	/tb/notification/detail
# popup-api	알림 상세(Detail) 등록	post	알림 상세(Detail) 정보 등록합니다.	/tb/notification/detail
# popup-api	알림창 상세(Detail) 단건 조회	get	알림창 상세 정보를 단건 조회합니다.	/tb/notification/detail/{notificationDetailSeq}
# popup-api	알림창 상세 삭제(Detail)	delete	알림창 Detail 정보를 삭제합니다.	/tb/notification/detail/{notificationDetailSeq}
# popup-api	알림 상세(Detail) 수정	patch	알림 상세(Detail) 정보 수정합니다.	/tb/notification/detail/{notificationDetailSeq}
# popup-api	알림창 마스터(Master) 단건 조회	get	알림창 마스터 정보를 단건 조회합니다.	/tb/notification/{notificationSeq}
# popup-api	알림창 삭제(Master)	delete	알림창 Master 정보를 삭제합니다.	/tb/notification/{notificationSeq}
# popup-api	알림 마스터(Master) 수정	patch	알림 마스터(Master) 정보 수정합니다.	/tb/notification/{notificationSeq}
# popup-api	팝업 마스터(Master) 목록 조회	get	팝업 마스터 정보를 목록 조회합니다.	/tb/popup
# popup-api	팝업 마스터(Master) 등록	post	팝업 마스터(Master) 정보를 등록합니다.	/tb/popup
# popup-api	팝업 상세(Detail) 목록 조회	get	팝업 상세 정보를 목록 조회합니다.	/tb/popup/detail
# popup-api	팝업 상세(Detail) 등록	post	팝업 상세(Detail) 정보를 등록합니다.	/tb/popup/detail
# popup-api	팝업 상세(Detail) 단건 조회	get	팝업 상세 정보를 단건 조회합니다.	/tb/popup/detail/{popupDetailSeq}
# popup-api	팝업 상세(Detail) 삭제	delete	팝업 Detail 정보를 삭제합니다.	/tb/popup/detail/{popupDetailSeq}
# popup-api	팝업 상세(Detail) 수정	patch	팝업 상세(Detail) 정보를 수정합니다.	/tb/popup/detail/{popupDetailSeq}
# popup-api	팝업 마스터(Master) 단건 조회	get	팝업 마스터 정보를 단건 조회합니다.	/tb/popup/{popupSeq}
# popup-api	팝업 마스터(Master) 삭제	delete	팝업 Master 정보를 삭제합니다.	/tb/popup/{popupSeq}
# popup-api	팝업 마스터(Master) 수정	patch	팝업 마스터(Master) 정보를 수정합니다.	/tb/popup/{popupSeq}
# projectinfo-api	프로젝트 조회	post		/project
# projectinfo-api	프로젝트 수정	patch		/project
# projectinfo-api	프로젝트 등록	post		/project/regist
# projectinfo-api	프로젝트 상세조회	get		/project/{projectCd}
# projectinfo-api	프로젝트 전체 삭제	delete		/project/{projectCd}
# projectinfo-api	프로젝트 개별 삭제	delete		/project/{projectCd}/{langCd}
# projectinfo-api	사이트 정보 조회	post		/site
# projectinfo-api	사이트 정보 수정	patch		/site
# projectinfo-api	사이트 카테고리 조회	get		/site/detail-sub/{projectCd}/{siteId}
# projectinfo-api	사이트 카테고리 수정	put		/site/detail-sub/{projectCd}/{siteId}
# projectinfo-api	사이트 카테고리 정보 삭제	delete		/site/detail-sub/{projectCd}/{siteId}
# projectinfo-api	사이트 카테고리 다건 수정	put		/site/detail-sub/{projectCd}/{siteId}/multi
# projectinfo-api	사이트 카테고리 다건 입력	post		/site/detail-sub/{projectCd}/{siteId}/multi-regist
# projectinfo-api	사이트 카테고리 단건 입력	post		/site/detail-sub/{projectCd}/{siteId}/regist
# projectinfo-api	사이트 상세정보 조회	post		/site/detail/{projectCd}/{siteId}
# projectinfo-api	사이트 정보 삭제	delete		/site/detail/{projectCd}/{siteId}
# projectinfo-api	사이트 상세정보 단건 수정	patch		/site/detail/{projectCd}/{siteId}
# projectinfo-api	사이트 상세정보 다건 수정	patch		/site/detail/{projectCd}/{siteId}/multi
# projectinfo-api	사이트 상세정보 다건 입력	post		/site/detail/{projectCd}/{siteId}/multi-regist
# projectinfo-api	사이트 상세정보 단건 입력	post		/site/detail/{projectCd}/{siteId}/regist
# projectinfo-api	사이트 상세정보 단건 조회	get		/site/detail/{projectCd}/{siteId}/{langCd}
# projectinfo-api	사이트 대표 이메일 조회	post		/site/email
# projectinfo-api	사이트 대표 이메일 수정	patch		/site/email
# projectinfo-api	사이트 대표 이메일 등록	post		/site/email/regist
# projectinfo-api	사이트 대표 이메일 상세조회	get		/site/email/{siteEmailAccNo}
# projectinfo-api	사이트 대표 이메일 삭제	delete		/site/email/{siteEmailAccNo}
# projectinfo-api	사이트 언어 조회	post		/site/language
# projectinfo-api	사이트 언어 단건 수정	put		/site/language/{projectCd}/{siteId}
# projectinfo-api	사이트 언어 다건 수정	put		/site/language/{projectCd}/{siteId}/multi
# projectinfo-api	사이트 언어 다건 등록	post		/site/language/{projectCd}/{siteId}/multi-regist
# projectinfo-api	사이트 언어 단건 등록	post		/site/language/{projectCd}/{siteId}/regist
# projectinfo-api	사이트 언어 상세조회	get		/site/language/{projectCd}/{siteId}/{langCd}
# projectinfo-api	사이트 언어 삭제	delete		/site/language/{projectCd}/{siteId}/{langCd}
# projectinfo-api	사이트 레이아웃 수정	post		/site/layout/modify
# projectinfo-api	사이트 레이아웃 정보 조회	post		/site/layout/read
# projectinfo-api	사이트 레이아웃 섹션별 정보 조회	post		/site/layout/read/partition
# projectinfo-api	사이트 레이아웃 상세정보 조회	get		/site/layout/read/{layout_no}
# projectinfo-api	사이트 레이아웃 등록	post		/site/layout/regist
# projectinfo-api	사이트 레이아웃 삭제	post		/site/layout/remove
# projectinfo-api	사이트 연관링크 조회	post		/site/link
# projectinfo-api	사이트 연관링크 상세정보 삭제	post		/site/link/remove/detail/{siteLinkDetailNo}
# projectinfo-api	사이트 연관링크 삭제	post		/site/link/remove/{siteLinkNo}
# projectinfo-api	사이트 연관링크 등록	post		/site/link/{projectCd}/{siteId}/regist
# projectinfo-api	사이트 연관링크 상세정보 조회	get		/site/link/{siteLinkNo}
# projectinfo-api	사이트 연관링크 수정	patch		/site/link/{siteLinkNo}
# projectinfo-api	사이트 메뉴 조회	post		/site/menu
# projectinfo-api	사이트 메뉴 수정	patch		/site/menu
# projectinfo-api	/site/menu/copy/{projectCd}/{siteId}	post	메뉴 복제 API	/site/menu/copy/{projectCd}/{siteId}
# projectinfo-api	사이트 메뉴 등록	post		/site/menu/regist
# projectinfo-api	사이트 메뉴 상세조회	get		/site/menu/{menuNo}
# projectinfo-api	사이트 삭제	delete		/site/menu/{menuNo}
# projectinfo-api	사이트 언어별 삭제	delete		/site/menu/{menuNo}/{langCd}
# projectinfo-api	네비게이션바 수정	post		/site/navibar/modify
# projectinfo-api	네비게이션바 정보 조회	post		/site/navibar/read
# projectinfo-api	네비게이션바 섹션별 분리 조회	post		/site/navibar/read/parition
# projectinfo-api	네비게이션바 상세정보 조회	get		/site/navibar/read/{navi_no}
# projectinfo-api	네비게이션바 등록	post		/site/navibar/regist
# projectinfo-api	네비게이션바 삭제	post		/site/navibar/remove
# projectinfo-api	사이트 정보 등록	post		/site/regist
# projectinfo-api	사이트 정보 단건 조회	get		/site/{projectCd}/{siteId}
# projectinfo-api	사이트 정보 삭제	delete		/site/{projectCd}/{siteId}
# projectinfo2-api	프로젝트 상세 수정	post		/project/detail/modify
# projectinfo2-api	프로젝트 상세 등록	post		/project/detail/register
# projectinfo2-api	프로젝트 상세삭제	post		/project/detail/remove
# projectinfo2-api	프로젝트 상세 조회	get		/project/detail/{project_cd}/{lang_cd}
# projectinfo2-api	프로젝트 수정	post		/project/modify
# projectinfo2-api	프로젝트 조회	post		/project/read
# projectinfo2-api	사이트 정보 조회	post		/project/read/duplicate-check
# projectinfo2-api	프로젝트 상세조회	get		/project/read/{project_cd}
# projectinfo2-api	프로젝트 등록	post		/project/register
# projectinfo2-api	프로젝트 전체 삭제	post		/project/remove
# projectinfo2-api	사이트 상세옵션 단건 수정	post		/site/config/modify
# projectinfo2-api	사이트 상세옵션 다건 수정	post		/site/config/multi-modify
# projectinfo2-api	사이트 상세옵션 다건 입력	post		/site/config/multi-register
# projectinfo2-api	사이트 상세옵션 configId 로 다건 수정	post		/site/config/multi-update
# projectinfo2-api	사이트 상세옵션 조회	get		/site/config/read/{project_cd}/{site_id}
# projectinfo2-api	사이트 상세옵션 단건 입력	post		/site/config/register
# projectinfo2-api	사이트 상세옵션 단건 삭제	post		/site/config/remove
# projectinfo2-api	사이트 카테고리 단건 수정	post		/site/detail-sub/modify
# projectinfo2-api	사이트 카테고리 다건 수정	post		/site/detail-sub/multi-modify
# projectinfo2-api	사이트 카테고리 다건 입력	post		/site/detail-sub/multi-register
# projectinfo2-api	사이트 카테고리 조회	get		/site/detail-sub/read/{project_cd}/{site_id}
# projectinfo2-api	사이트 카테고리 단건 입력	post		/site/detail-sub/register
# projectinfo2-api	사이트 카테고리 단건 삭제	post		/site/detail-sub/remove
# projectinfo2-api	사이트 상세정보 단건 수정	post		/site/detail/modify
# projectinfo2-api	사이트 상세정보 조회	post		/site/detail/read/{project_cd}/{site_id}
# projectinfo2-api	사이트 상세정보 단건 입력	post		/site/detail/register
# projectinfo2-api	사이트 상세정보 단건 삭제	post		/site/detail/remove
# projectinfo2-api	사이트 언어 단건 수정	post		/site/language/modify
# projectinfo2-api	사이트 언어 다건 수정	post		/site/language/multi-modify
# projectinfo2-api	사이트 언어 다건 등록	post		/site/language/multi-register
# projectinfo2-api	사이트 언어 조회	post		/site/language/read
# projectinfo2-api	사이트 언어 상세조회	get		/site/language/read/{project_cd}/{site_id}/{lang_cd}
# projectinfo2-api	사이트 언어 단건 등록	post		/site/language/register
# projectinfo2-api	사이트 언어 삭제	post		/site/language/remove
# projectinfo2-api	사이트 레이아웃 수정	post		/site/layout/modify
# projectinfo2-api	사이트 레이아웃 출력순서 수정	post		/site/layout/modify-order
# projectinfo2-api	사이트 레이아웃 정보 조회	post		/site/layout/read
# projectinfo2-api	사이트 레이아웃 섹션별 정보 조회	post		/site/layout/read/partition
# projectinfo2-api	사이트 레이아웃 상세정보 조회	get		/site/layout/read/{layout_no}
# projectinfo2-api	사이트 레이아웃 등록	post		/site/layout/register
# projectinfo2-api	사이트 레이아웃 삭제	post		/site/layout/remove
# projectinfo2-api	사이트 연관링크 상세정보 삭제	post		/site/link/detail/remove
# projectinfo2-api	사이트 연관링크 수정	post		/site/link/modify
# projectinfo2-api	사이트 연관링크 조회	post		/site/link/read
# projectinfo2-api	사이트 연관링크 상세정보 조회	get		/site/link/read/{site_link_no}
# projectinfo2-api	사이트 연관링크 등록	post		/site/link/register
# projectinfo2-api	사이트 연관링크 삭제	post		/site/link/remove
# projectinfo2-api	메뉴 복제	post		/site/menu/copy-menu
# projectinfo2-api	사이트 메뉴상세 삭제	post		/site/menu/detail/remove
# projectinfo2-api	사이트 메뉴 수정	post		/site/menu/modify
# projectinfo2-api	사이트 메뉴 정렬순서 수정	post		/site/menu/modify-order
# projectinfo2-api	사이트 메뉴 조회	post		/site/menu/read
# projectinfo2-api	사이트 메뉴 조회	post		/site/menu/read/partition
# projectinfo2-api	사이트 메뉴 상세조회	get		/site/menu/read/{menu_no}
# projectinfo2-api	사이트 메뉴 등록	post		/site/menu/register
# projectinfo2-api	사이트 메뉴 삭제	post		/site/menu/remove
# projectinfo2-api	메뉴 기본값 초기화	post		/site/menu/reset-menu
# projectinfo2-api	사이트 정보 수정	post		/site/modify
# projectinfo2-api	네비게이션바 복제	post		/site/navibar/copy-navibar
# projectinfo2-api	네비게이션바 수정	post		/site/navibar/modify
# projectinfo2-api	네비게이션바 출력순서 수정	post		/site/navibar/modify-order
# projectinfo2-api	네비게이션바 정보 조회	post		/site/navibar/read
# projectinfo2-api	네비게이션바 섹션별 분리 조회	post		/site/navibar/read/partition
# projectinfo2-api	네비게이션바 상세정보 조회	get		/site/navibar/read/{navi_no}
# projectinfo2-api	네비게이션바 등록	post		/site/navibar/register
# projectinfo2-api	네비게이션바 삭제	post		/site/navibar/remove
# projectinfo2-api	네비게이션바 초기화	post		/site/navibar/reset-navibar
# projectinfo2-api	사이트 정보 조회	post		/site/read
# projectinfo2-api	사이트 정보 조회	post		/site/read/duplicate-check
# projectinfo2-api	사이트 아이디 난수발급	post		/site/read/site-id-generater
# projectinfo2-api	사이트 정보 단건 조회	get		/site/read/{project_cd}/{site_id}
# projectinfo2-api	사이트 정보 등록	post		/site/register
# projectinfo2-api	사이트 정보 삭제	post		/site/remove
# quiz-api	퀴즈 상품목록 조회	get		/admin/goods
# quiz-api	퀴즈 상품 등록	post		/admin/goods
# quiz-api	퀴즈 상품 수정	patch		/admin/goods
# quiz-api	퀴즈 상품 히스토리 목록 조회 	get		/admin/goods/history
# quiz-api	퀴즈 상품 히스토리 개별 조회 	get		/admin/goods/history/{historyNo}
# quiz-api	퀴즈 상품 히스토리 삭제(논리)	delete		/admin/goods/history/{historyNo}
# quiz-api	퀴즈 상품 포인트 목록 조회 	get		/admin/goods/point
# quiz-api	퀴즈 상품 포인트 적립	patch		/admin/goods/point/plus
# quiz-api	퀴즈 상품 포인트 차감	patch		/admin/goods/point/sub
# quiz-api	퀴즈 상품 포인트 개별 조회 	get		/admin/goods/point/{userNo}
# quiz-api	퀴즈 상품목록 개별조회	get		/admin/goods/{goodsNo}
# quiz-api	퀴즈 상품 삭제(논리)	delete		/admin/goods/{goodsNo}
# quiz-api	퀴즈 그룹>문항>보기>답안 조회	get		/admin/group
# quiz-api	퀴즈 그룹&사이트 조회	get		/admin/group/site
# quiz-api	퀴즈 그룹&사이트 등록	post		/admin/group/site
# quiz-api	퀴즈 그룹&사이트 수정	patch		/admin/group/site
# quiz-api	퀴즈 그룹&사이트 단건 조회	get		/admin/group/site/{groupNo}
# quiz-api	퀴즈 그룹>문항>보기>답안 상세보기	get		/admin/group/{groupNo}
# quiz-api	퀴즈 링크 조회	get		/admin/link
# quiz-api	퀴즈 링크 등록	post		/admin/link
# quiz-api	퀴즈 링크 수정	patch		/admin/link
# quiz-api	퀴즈 링크 개별 조회	get		/admin/link/{linkNo}
# quiz-api	퀴즈 링크 삭제(논리)	delete		/admin/link/{linkNo}
# quiz-api	퀴즈 조회	get		/admin/qna
# quiz-api	퀴즈 등록	post		/admin/qna
# quiz-api	퀴즈 수정	patch		/admin/qna
# quiz-api	퀴즈 답변 목록	get		/admin/qna/answer
# quiz-api	퀴즈 답변 삭제(논리)	delete		/admin/qna/answer/{answerNo}
# quiz-api	퀴즈 답안 목록	get		/admin/qna/example
# quiz-api	퀴즈 답안 삭제(논리)	delete		/admin/qna/example/{exampleNo}
# quiz-api	퀴즈 질문 목록	get		/admin/qna/question
# quiz-api	퀴즈 문항 삭제(논리)	delete		/admin/qna/question/{questionNo}
# quiz-api	퀴즈 삭제(전체 삭제)	delete		/admin/qna/{questionNo}
# quiz-api	퀴즈 상세조회	get		/admin/qna/{questionNo}/{langCd}
# quiz-api	퀴즈 사이트 조회	get		/admin/site
# quiz-api	퀴즈 사이트 등록(단건)	post		/admin/site
# quiz-api	퀴즈 사이트 수정	patch		/admin/site
# quiz-api	퀴즈 사이트 등록(멀티)	post		/admin/site/multi
# quiz-api	퀴즈 사이트 개별 조회	get		/admin/site/{siteNo}
# ...
# subscribe-api	회사 사이트 정보 단건 삭제	delete	회사 사이트 정보 단건 삭제	/company/site/{siteCompanyNo}
# subscribe-api	회사 사이트 정보 단건 수정	patch	회사 사이트 정보 단건 수정	/company/site/{siteCompanyNo}
# subscribe-api	회사 단건 조회	get	회사, 상세, 서브 한번에 조회	/company/{companyNo}
# subscribe-api	회사 삭제	delete	회사 삭제	/company/{companyNo}
# subscribe-api	회사 수정	patch	회사, 상세, 서브 한번에 수정	/company/{companyNo}
# subscribe-api	직원 정보 목록 api	get	직원 정보 목록 api	/emp
# subscribe-api	직원 등록 api	post	직원 등록 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 insert한다.<br/> 해당 회사의 첫 번째 직원이면 : 모든 권한 부여 O 아니면 모든 권한 부여 X	/emp
# subscribe-api	직원 상세 정보 등록 api	post	직원 상세정보 등록 api<br/> request parameter 형식: array	/emp/detail
# subscribe-api	직원 상세 정보 수정 api	patch	직원 상세정보 수정 api<br/> request parameter 형식: array	/emp/detail
# subscribe-api	직원 상세 서브 정보 등록 api	post	직원 상세 서브 정보 등록	/emp/detail-sub
# subscribe-api	직원 상세 서브 정보 수정 api	patch	직원 상세 서브 정보 수정 api	/emp/detail-sub
# subscribe-api	직원 상세 서브 정보 삭제 api	delete	직원 상세 서브 정보 삭제 api	/emp/detail-sub/{empDetailSubSeq}
# subscribe-api	직원 상세 정보 삭제 api	delete	직원 상세 정보 삭제 api<br/> 로그인 한 유저가 본인의 것만 삭제 가능하도록 함.	/emp/detail/{empNo}
# subscribe-api	직원 언어에 해당하는 정보 api	get	직원 언어에 해당하는 정보 api (유저 정보까지 포함)	/emp/{empNo}
# subscribe-api	직원 삭제 api	delete	직원 삭제 api<br/> 로그인 한 유저가 삭제 가능하도록 함.	/emp/{empNo}
# subscribe-api	직원 수정 api	patch	직원 수정 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 update한다.	/emp/{empNo}
# subscribe-api	직원 언어에 해당하는 정보 api	get	직원 언어에 해당하는 정보 api	/emp/{projectCd}/{siteId}/{companyNo}/{userNo}
# subscribe-api	유저 목록 api	get	유저 목록 api	/user
# subscribe-api	유저 전체 등록	post	유저, 상세, 서브 한번에 등록	/user
# subscribe-api	유저 탈퇴 api	delete	유저 탈퇴 api	/user
# subscribe-api	유저 수정	patch	유저 수정	/user
# subscribe-api	유저 상세 정보 등록	post	유저 상세정보만 등록	/user/detail
# subscribe-api	유저 상세 정보 삭제 api	delete	유저 상세 정보 삭제 api	/user/detail
# subscribe-api	유저 상세 정보 수정	patch	유저 상세정보만 수정	/user/detail
# subscribe-api	유저 상세 서브 정보 전체 삭제 후 입력	put	유저 상세 서브 전체 삭제 후 입력	/user/detail-sub
# subscribe-api	유저 서브 정보 등록	post	유저 서브정보만 등록	/user/detail-sub
# subscribe-api	유저 서브 정보 수정	patch	유저 서브정보만 수정	/user/detail-sub
# subscribe-api	유저 상세 서브 정보 삭제 api	delete	유저 상세 서브 정보 삭제 api	/user/detail-sub/{userDetailSubSeq}
# subscribe-api	유저 서브 정보 수정	patch	유저 서브정보만 수정	/user/detail-sub/{userDetailSubSeq}
# subscribe-api	유저 아이디 중복 체크	get	아이디 중복 체크	/user/duplication/{userId}
# subscribe-api	내 정보 api	get	내 정보 api	/user/me
# subscribe-api	유저 통합 등록(통합회원가입, 행사등록)	post	통합회원가입, 행사 한번에 등록	/user/service
# subscribe-api	유저 통합 등록 아이디 중복 체크	get	아이디 중복 체크	/user/service/duplication/{userId}/{siteId}
# subscribe-api	유저 행사 정보	get	유저 행사 정보	/user/site
# subscribe-api	유저 행사 정보 등록	post	유저 행사 정보 등록	/user/site
# subscribe-api	행사 유저 탈퇴	delete	행사 유저 탈퇴	/user/site
# subscribe-api	행사 유저 역할 등록	post	행사 유저 역할 등록	/user/site-part
# subscribe-api	행사 유저 역할 수정	patch	행사 유저 역할 수정	/user/site-part/{siteUserPartNo}
# subscribe-api	유저 여부 확인	post	이메일 이용하여 siteUser 정보 조회	/user/site/find
# subscribe-api	행사 유저 수정	patch	행사 유저 수정	/user/site/{projectCd}/{siteId}
# subscribe-api	유저 행사 정보	get	유저 행사 정보	/user/site/{siteUserNo}
# subscribe-api	행사 유저 수정	patch	행사 유저 수정	/user/site/{siteUserNo}
# subscribe-api	유저 언어에 따른 정보 api	get	유저 언어에 따른 정보 api	/user/{userNo}
# survey2-api	관리자 질문 & 답변 등록	post		/admin/qna
# survey2-api	관리자 질문 & 답변 수정	patch		/admin/qna
# survey2-api	관리자 답변 목록	get		/admin/qna/answer
# survey2-api	관리자 답변 등록	post		/admin/qna/answer
# survey2-api	관리자 답변 수정	patch		/admin/qna/answer
# survey2-api	관리자 답변 삭제(논리)	delete		/admin/qna/answer/{answerNo}
# survey2-api	관리자 질문 목록	get		/admin/qna/question
# survey2-api	관리자 질문 등록	post		/admin/qna/question
# survey2-api	관리자 질문 수정	patch		/admin/qna/question
# survey2-api	관리자 질문 & 답변 삭제(논리)	delete		/admin/qna/{questionNo}
# survey2-api	관리자 페이지 섹션 등록	post		/admin/section
# survey2-api	관리자 페이지 섹션 수정	patch		/admin/section
# survey2-api	섹션>문항>답변 상세정보	get		/admin/section/{sectionNo}
# survey2-api	관리자 페이지 섹션 삭제	delete		/admin/section/{sectionNo}
# survey2-api	관리자 페이지 설문 등록	post		/admin/survey
# survey2-api	관리자 페이지 설문 수정	patch		/admin/survey
# survey2-api	관리자 페이지 설문 삭제	delete		/admin/survey/{surveyNo}
# survey2-api	사용자 답변 제출(멀티)	post		/multi/submit
# survey2-api	사용자 답변 제출 수정(멀티)	patch		/multi/submit
# survey2-api	섹션>문항>답변 목록	get		/section
# survey2-api	프로그램 및 세션별 섹션>문항>답변 상세정보	get		/section/{refKey}/{refId}
# survey2-api	섹션>문항>답변 상세정보	get		/section/{sectionNo}
# survey2-api	유저 제출 목록	get		/submit
# survey2-api	사용자 답변 제출	post		/submit
# survey2-api	사용자 답변 제출 수정	patch		/submit
# survey2-api	사용자 답변 삭제	delete		/submit/{submitNo}
# survey2-api	설문 참여 여부	get		/submitCheck
# survey2-api	설문>섹션>문항>답변 목록	get		/survey
# survey2-api	설문>섹션>문항>답변 상세정보	get		/survey/{refKey}/{refId}
# survey2-api	설문>섹션>문항>답변 상세정보	get		/survey/{surveyNo}
# survey2-api	답변 목록	get		/tb/answer
# survey2-api	답변 등록	post		/tb/answer
# survey2-api	답변 수정	patch		/tb/answer
# survey2-api	답변상세 목록	get		/tb/answer/detail
# survey2-api	답변상세 등록	post		/tb/answer/detail
# survey2-api	답변상세 수정	patch		/tb/answer/detail
# survey2-api	답변상세 정보	get		/tb/answer/detail/{answerDetailNo}
# survey2-api	답변상세 삭제(논리)	delete		/tb/answer/detail/{answerDetailNo}
# survey2-api	답변상세 삭제(물리)	delete		/tb/answer/detail/{userNo}/{answerDetailNo}
# survey2-api	답변 상세정보	get		/tb/answer/{answerNo}
# survey2-api	답변 삭제(논리)	delete		/tb/answer/{answerNo}
# survey2-api	답변 삭제(물리)	delete		/tb/answer/{userNo}/{answerNo}
# survey2-api	파일 목록	get		/tb/attach
# survey2-api	파일 등록	post		/tb/attach
# survey2-api	파일 수정	patch		/tb/attach
# survey2-api	파일 다운로드	get		/tb/attach/download/{attachGrpCd}
# survey2-api	오투미트 설문 파일 다운로드	get		/tb/attach/download/{projectCd}/{siteId}/{attachGrpCd}
# survey2-api	파일 상세정보	get		/tb/attach/{attachGrpCd}
# survey2-api	파일 삭제(논리)	delete		/tb/attach/{attachGrpCd}
# survey2-api	파일 삭제(물리)	delete		/tb/attach/{userNo}/{attachGrpCd}
# survey2-api	문항 목록	get		/tb/question
# survey2-api	문항 등록	post		/tb/question
# survey2-api	문항 수정	patch		/tb/question
# survey2-api	문항상세 목록	get		/tb/question/detail
# survey2-api	문항상세 등록	post		/tb/question/detail
# survey2-api	문항상세 수정	patch		/tb/question/detail
# survey2-api	문항상세 정보	get		/tb/question/detail/{questionDetailNo}
# survey2-api	문항상세 삭제(논리)	delete		/tb/question/detail/{questionDetailNo}
# survey2-api	문항상세 삭제(물리)	delete		/tb/question/detail/{userNo}/{questionDetailNo}
# survey2-api	문항 상세정보	get		/tb/question/{questionNo}
# survey2-api	문항 삭제(논리)	delete		/tb/question/{questionNo}
# survey2-api	문항 삭제(물리)	delete		/tb/question/{userNo}/{questionNo}
# survey2-api	기록관리 목록	get		/tb/record
# survey2-api	기록관리 등록	post		/tb/record
# survey2-api	기록관리 수정	patch		/tb/record
# survey2-api	기록관리 상세정보	get		/tb/record/{recordNo}
# survey2-api	기록관리 삭제(논리)	delete		/tb/record/{recordNo}
# survey2-api	점수구간별 기록관리 정보	get		/tb/record/{sectionNo}/{totalScore}
# survey2-api	기록관리 삭제(물리)	delete		/tb/record/{userNo}/{recordNo}
# survey2-api	섹션 목록	get		/tb/section
# survey2-api	섹션 등록	post		/tb/section
# survey2-api	섹션 수정	patch		/tb/section
# survey2-api	섹션상세 목록	get		/tb/section/detail
# survey2-api	섹션상세 등록	post		/tb/section/detail
# survey2-api	섹션상세 수정	patch		/tb/section/detail
# survey2-api	섹션상세 조회	get		/tb/section/detail/{sectionDetailNo}
# survey2-api	섹션상세 삭제(논리)	delete		/tb/section/detail/{sectionDetailNo}
# survey2-api	섹션상세 삭제(물리)	delete		/tb/section/detail/{userNo}/{sectionDetailNo}
# survey2-api	섹션 상세정보	get		/tb/section/{sectionNo}
# survey2-api	섹션 삭제(논리)	delete		/tb/section/{sectionNo}
# survey2-api	섹션 삭제(물리)	delete		/tb/section/{userNo}/{sectionNo}
# survey2-api	제출 목록	get		/tb/submit
# survey2-api	제출 등록	post		/tb/submit
# survey2-api	제출 수정	patch		/tb/submit
# survey2-api	제출상세 목록	get		/tb/submit/detail
# survey2-api	제출상세 등록	post		/tb/submit/detail
# survey2-api	제출상세 수정	patch		/tb/submit/detail
# survey2-api	제출상세 정보	get		/tb/submit/detail/{submitDetailNo}
# survey2-api	제출상세 삭제(논리)	delete		/tb/submit/detail/{submitDetailNo}
# survey2-api	제출상세 삭제(물리)	delete		/tb/submit/detail/{userNo}/{submitDetailNo}
# survey2-api	제출점수 목록	get		/tb/submit/score
# survey2-api	제출점수 등록	post		/tb/submit/score
# survey2-api	제출점수 수정	patch		/tb/submit/score
# survey2-api	제출점수 정보	get		/tb/submit/score/{scoreNo}
# survey2-api	제출점수 삭제(논리)	delete		/tb/submit/score/{scoreNo}
# survey2-api	제출점수 삭제(물리)	delete		/tb/submit/score/{userNo}/{scoreNo}
# survey2-api	제출 상세정보	get		/tb/submit/{submitNo}
# survey2-api	제출 삭제(논리)	delete		/tb/submit/{submitNo}
# survey2-api	제출 삭제(물리)	delete		/tb/submit/{userNo}/{submitNo}
# survey2-api	설문 목록	get		/tb/survey
# survey2-api	설문 등록	post		/tb/survey
# survey2-api	설문 수정	patch		/tb/survey
# survey2-api	설문상세 목록	get		/tb/survey/detail
# survey2-api	설문상세 등록	post		/tb/survey/detail
# survey2-api	설문상세 수정	patch		/tb/survey/detail
# survey2-api	설문상세 정보	get		/tb/survey/detail/{surveyDetailNo}
# survey2-api	설문상세 삭제(논리)	delete		/tb/survey/detail/{surveyDetailNo}
# survey2-api	설문상세 삭제(물리)	delete		/tb/survey/detail/{userNo}/{surveyDetailNo}
# survey2-api	설문 상세정보	get		/tb/survey/{surveyNo}
# survey2-api	설문 삭제(논리)	delete		/tb/survey/{surveyNo}
# survey2-api	설문 삭제(물리)	delete		/tb/survey/{userNo}/{surveyNo}
# user-api	회사 목록 조회	get	회사 목록 조회	/admin/company
# user-api	회사 전체 등록	post	회사, 상세, 서브 한번에 등록	/admin/company
# user-api	회사 상세 정보 등록	post	회사 상세 정보 등록	/admin/company/detail
# user-api	회사 상세 정보 수정	patch	회사 상세 정보 수정	/admin/company/detail
# user-api	회사 서브 정보 등록	post	회사 서브 정보 등록	/admin/company/detail-sub
# user-api	회사 서브 정보 수정	patch	회사 서브 정보 수정	/admin/company/detail-sub
# user-api	회사 서브 정보 삭제	delete	회사 서브 정보 삭제	/admin/company/detail-sub/{companyDetailSubSeq}
# user-api	회사 상세 정보 삭제	delete	회사 상세 정보 삭제	/admin/company/detail/{companyNo}
# user-api	회사 조회	get	회사, 상세, 서브 한번에 조회	/admin/company/{companyNo}
# user-api	회사 삭제	delete	회사 삭제	/admin/company/{companyNo}
# user-api	회사 수정	patch	회사, 상세, 서브 한번에 수정	/admin/company/{companyNo}
# user-api	직원 정보 목록 api	get	직원 정보 목록 api	/admin/emp
# user-api	직원 등록 api	post	직원 등록 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 insert한다.	/admin/emp
# user-api	직원 상세 정보 등록 api	post	직원 상세정보 등록 api<br/> request parameter 형식: array	/admin/emp/detail
# user-api	직원 상세 정보 수정 api	patch	직원 상세정보 수정 api<br/> request parameter 형식: array	/admin/emp/detail
# user-api	직원 상세 서브 정보 등록 api	post	직원 상세 서브 정보 등록	/admin/emp/detail-sub
# user-api	직원 상세 서브 정보 수정 api	patch	직원 상세 서브 정보 수정 api	/admin/emp/detail-sub
# user-api	직원 상세 서브 정보 삭제 api	delete	직원 상세 서브 정보 삭제 api	/admin/emp/detail-sub/{empDetailSubSeq}
# user-api	직원 상세 정보 삭제 api	delete	직원 상세 정보 삭제 api<br/> 로그인 한 유저가 본인의 것만 삭제 가능하도록 함.	/admin/emp/detail/{empNo}
# user-api	직원 언어에 해당하는 정보 api	get	직원 언어에 해당하는 정보 api (유저 정보까지 포함)	/admin/emp/{empNo}
# user-api	직원 삭제 api	delete	직원 삭제 api<br/> 로그인 한 유저가 본인의 것만 삭제 가능하도록 함.	/admin/emp/{empNo}
# user-api	직원 수정 api	patch	직원 수정 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 update한다.	/admin/emp/{empNo}
# user-api	유저 목록 api	get	유저 목록 api	/admin/user
# user-api	유저 전체 등록	post	유저, 상세, 서브 한번에 등록	/admin/user
# user-api	유저 회사 정보 api	get	유저 회사 정보 조회 api	/admin/user/company
# user-api	유저 상세 정보 등록	post	유저 상세정보만 등록	/admin/user/detail
# user-api	유저 상세 정보 수정	patch	유저 상세정보만 수정	/admin/user/detail
# user-api	유저 서브 정보 등록	post	유저 서브정보만 등록	/admin/user/detail-sub
# user-api	유저 서브 정보 수정	patch	유저 서브정보만 수정	/admin/user/detail-sub
# user-api	유저 상세 서브 정보 api	delete	유저 상세 서브 정보 삭제 api	/admin/user/detail-sub/{userDetailSubSeq}
# user-api	유저 상세 정보 삭제 api	delete	유저 상세 정보 삭제 api	/admin/user/detail/{userNo}
# user-api	내 정보 api	get	내 정보 api	/admin/user/me
# user-api	유저 행사 정보 등록	post	유저 행사 정보 등록	/admin/user/site
# user-api	행사 유저 역할 등록	post	행사 유저 역할 등록	/admin/user/site-part
# user-api	siteUserNo 이용하여 행사 유저 역할 수정	patch	siteUserNo 이용하여 행사 유저 역할 수정	/admin/user/site-part/{siteUserNo}
# user-api	행사 유저 역할 수정	patch	행사 유저 역할 수정	/admin/user/site-part/{siteUserPartNo}
# user-api	행사 유저 탈퇴	delete	행사 유저 탈퇴	/admin/user/site/{siteUserNo}
# user-api	행사 유저 수정	patch	행사 유저 수정	/admin/user/site/{siteUserNo}
# user-api	유저 언어에 따른 정보 api	get	유저 언어에 따른 정보 api	/admin/user/{userNo}
# user-api	유저 삭제 api	delete	유저 삭제 api	/admin/user/{userNo}
# user-api	유저 수정	patch	유저 수정	/admin/user/{userNo}
# user-api	회사 목록 조회	get	회사 목록 조회	/company
# user-api	회사 전체 등록	post	회사, 상세, 서브 한번에 등록	/company
# user-api	회사 상세 정보 등록	post	회사 상세 정보 등록	/company/detail
# user-api	회사 상세 정보 수정	patch	회사 상세 정보 수정	/company/detail
# user-api	회사 서브 정보 목록 조회	get	회사 서브 정보 목록 조회	/company/detail-sub
# user-api	회사 서브 정보 단건 수정	put	회사 서브 정보 단건 수정	/company/detail-sub
# user-api	회사 서브 정보 등록	post	회사 서브 정보 등록	/company/detail-sub
# user-api	회사 서브 정보 멀티 수정	patch	회사 서브 정보 멀티 수정	/company/detail-sub
# user-api	회사 서브 정보 삭제	delete	회사 서브 정보 삭제	/company/detail-sub/{companyDetailSubSeq}
# user-api	회사 상세 정보 삭제	delete	회사 상세 정보 삭제	/company/detail/{companyNo}
# user-api	회사 사이트 정보 목록 출력	get	회사 사이트 정보 목록 출력	/company/site
# user-api	회사 사이트 정보 단건 등록	post	회사 사이트 정보 단건 등록	/company/site
# user-api	회사 사이트 상세 정보 멀티 등록	post	회사 사이트 상세 정보 멀티 등록	/company/site/detail/{siteCompanyNo}
# user-api	회사 사이트 상세 정보 멀티 삭제	delete	회사 사이트 상세 정보 멀티 삭제	/company/site/detail/{siteCompanyNo}
# user-api	회사 사이트 상세 정보 멀티 수정	patch	회사 사이트 상세 정보 멀티 수정	/company/site/detail/{siteCompanyNo}
# user-api	회사 사이트 정보 단건 조회	get	회사 사이트 단건 조회	/company/site/{siteCompanyNo}
# user-api	회사 사이트 정보 단건 삭제	delete	회사 사이트 정보 단건 삭제	/company/site/{siteCompanyNo}
# user-api	회사 사이트 정보 단건 수정	patch	회사 사이트 정보 단건 수정	/company/site/{siteCompanyNo}
# user-api	회사 단건 조회	get	회사, 상세, 서브 한번에 조회	/company/{companyNo}
# user-api	회사 삭제	delete	회사 삭제	/company/{companyNo}
# user-api	회사 수정	patch	회사, 상세, 서브 한번에 수정	/company/{companyNo}
# user-api	직원 정보 목록 api	get	직원 정보 목록 api	/emp
# user-api	직원 등록 api	post	직원 등록 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 insert한다.<br/> 해당 회사의 첫 번째 직원이면 : 모든 권한 부여 O 아니면 모든 권한 부여 X	/emp
# user-api	직원 상세 정보 등록 api	post	직원 상세정보 등록 api<br/> request parameter 형식: array	/emp/detail
# user-api	직원 상세 정보 수정 api	patch	직원 상세정보 수정 api<br/> request parameter 형식: array	/emp/detail
# user-api	직원 상세 서브 정보 등록 api	post	직원 상세 서브 정보 등록	/emp/detail-sub
# user-api	직원 상세 서브 정보 수정 api	patch	직원 상세 서브 정보 수정 api	/emp/detail-sub
# user-api	직원 상세 서브 정보 삭제 api	delete	직원 상세 서브 정보 삭제 api	/emp/detail-sub/{empDetailSubSeq}
# user-api	직원 상세 정보 삭제 api	delete	직원 상세 정보 삭제 api<br/> 로그인 한 유저가 본인의 것만 삭제 가능하도록 함.	/emp/detail/{empNo}
# user-api	직원 언어에 해당하는 정보 api	get	직원 언어에 해당하는 정보 api (유저 정보까지 포함)	/emp/{empNo}
# user-api	직원 삭제 api	delete	직원 삭제 api<br/> 로그인 한 유저가 삭제 가능하도록 함.	/emp/{empNo}
# user-api	직원 수정 api	patch	직원 수정 api <br/>detail과 detail_sub 데이터도 list 형식으로 포함하여 넘기면 같이 update한다.	/emp/{empNo}
# user-api	직원 언어에 해당하는 정보 api	get	직원 언어에 해당하는 정보 api	/emp/{projectCd}/{siteId}/{companyNo}/{userNo}
# user-api	상담원 계정 초대 목록 조회 api	get	상담원 계정 초대 목록 조회 api (invtNo 내림차순 정렬)	/siteUserInvite
# user-api	상담원 계정 초대 api	post	상담원 계정 초대 api	/siteUserInvite
# user-api	토큰 인증 api	get	토큰을 받아서 정보를 내려준다	/siteUserInvite/token
# user-api	토큰 발행 api	post	정보를 받아서 토큰을 내려준다	/siteUserInvite/token
# user-api	상담원 계정 초대 조회 api	get	상담원 계정 초대 조회 api	/siteUserInvite/{invtNo}
# user-api	상담원 계정 초대 삭제 api	delete		/siteUserInvite/{invtNo}
# user-api	상담원 계정 초대 수정 api	patch		/siteUserInvite/{invtNo}
# user-api	유저 목록 api	get	유저 목록 api	/user
# user-api	유저 전체 등록	post	유저, 상세, 서브 한번에 등록	/user
# user-api	유저 탈퇴 api	delete	유저 탈퇴 api	/user
# user-api	유저 수정	patch	유저 수정	/user
# user-api	유저 상세 정보 등록	post	유저 상세정보만 등록	/user/detail
# user-api	유저 상세 정보 삭제 api	delete	유저 상세 정보 삭제 api	/user/detail
# user-api	유저 상세 정보 수정	patch	유저 상세정보만 수정	/user/detail
# user-api	유저 상세 서브 정보 전체 삭제 후 입력	put	유저 상세 서브 전체 삭제 후 입력	/user/detail-sub
# user-api	유저 서브 정보 등록	post	유저 서브정보만 등록	/user/detail-sub
# user-api	유저 서브 정보 수정	patch	유저 서브정보만 수정	/user/detail-sub
# user-api	유저 상세 서브 정보 삭제 api	delete	유저 상세 서브 정보 삭제 api	/user/detail-sub/{userDetailSubSeq}
# user-api	유저 서브 정보 수정	patch	유저 서브정보만 수정	/user/detail-sub/{userDetailSubSeq}
# user-api	유저 아이디 중복 체크	get	아이디 중복 체크	/user/duplication/{userId}
# user-api	내 정보 api	get	내 정보 api	/user/me
# user-api	유저 통합 등록(통합회원가입, 행사등록)	post	통합회원가입, 행사 한번에 등록	/user/service
# user-api	유저 통합 등록 아이디 중복 체크	get	아이디 중복 체크	/user/service/duplication/{userId}/{siteId}
# user-api	유저 행사 정보	get	유저 행사 정보	/user/site
# user-api	유저 행사 정보 등록	post	유저 행사 정보 등록	/user/site
# user-api	행사 유저 탈퇴	delete	행사 유저 탈퇴	/user/site
# user-api	행사 유저 역할 등록	post	행사 유저 역할 등록	/user/site-part
# user-api	행사 유저 역할 수정	patch	행사 유저 역할 수정	/user/site-part/{siteUserPartNo}
# user-api	유저 여부 확인	post	이메일 이용하여 siteUser 정보 조회	/user/site/find
# user-api	행사 유저 수정	patch	행사 유저 수정	/user/site/{projectCd}/{siteId}
# user-api	유저 행사 정보	get	유저 행사 정보	/user/site/{siteUserNo}
# user-api	행사 유저 수정	patch	행사 유저 수정	/user/site/{siteUserNo}
# user-api	유저 언어에 따른 정보 api	get	유저 언어에 따른 정보 api	/user/{userNo}
