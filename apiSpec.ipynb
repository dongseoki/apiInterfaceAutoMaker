# %%
import json
import os

# %%
f = open('./jsonDatas/order-api.json', encoding='utf8')
data =json.load(f)
apiDatas = data['paths']

# %%
data
# Out:
# {'openapi': '3.0.1',
#  'info': {'title': 'ORDER API', 'version': '1.0'},
#  'servers': [{'url': 'http://218.39.10.56:31470',
#    'description': 'Generated server url'}],
#  'security': [{'token': []}],
#  'tags': [{'name': 'ORDER GOODS', 'description': '주문상품'},
#   {'name': 'ORDER', 'description': '주문하기'},
#   {'name': 'Orders Programs', 'description': '주문 프로그램'},
#   {'name': 'Payment Method', 'description': '결제 방법'},
#   {'name': 'Orders Items', 'description': '주문 아이템'},
#   {'name': 'Orders Options', 'description': '주문 옵션'}],
#  'paths': {'/paymentMethod/project': {'post': {'tags': ['Payment Method'],
#     'summary': '해당 행사 결제 방법 조회',
#     'operationId': 'getPaymentMethodProject',
#     'parameters': [{'name': 'projectCd',
#       'in': 'query',
#       'required': False,
#       'schema': {'type': 'string'}},
#      {'name': 'siteId',
#       'in': 'query',
#       'required': False,
#       'schema': {'type': 'integer', 'format': 'int32'}},
#      {'name': 'delYn',
# ...
