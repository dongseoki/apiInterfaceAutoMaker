# %%
import os
# if not os.path.exists('./apiSpecGeneratorResult/my_folder'):
#    os.makedirs('./apiSpecGeneratorResult/my_folder')

# %%
relPath = './jsonDatas'
file_list = os.listdir(relPath)

# %%
apiFileCustomList = ['common-api.json']
apiFileCustomList.extend(sorted(file_list))

# %%
t = [1]
t.extend([2, 3])

# %%
t
# Out:
# [1, 2, 3]

# %%
apiFileCustomList
# Out:
# ['common-api.json',
#  'banner-api.json',
#  'board-api.json',
#  'category-api.json',
#  'common-api2.json',
#  'consulting-api.json',
#  'contents-api.json',
#  'counseling-api.json',
#  'coupon-api.json',
#  'goods-api.json',
#  'inquiry-api.json',
#  'logging-api.json',
#  'login2-api.json',
#  'mailing-api.json',
#  'mavatar-api.json',
#  'mbody-api.json',
#  'mcloth-api.json',
#  'mface-api.json',
#  'mhair-api.json',
#  'micecontents-api.json',
#  'mregion-api.json',
#  'mshoes-api.json',
#  'mypage-api.json',
#  'order-api.json',
#  'popup-api.json',
#  'projectinfo-api.json',
#  'projectinfo2-api.json',
#  'quiz-api.json',
#  'session-api.json',
#  'stat2-api.json',
#  'statistics-api.json',
#  'subscribe-api.json',
#  'survey2-api.json',
#  'user-api.json']

# %%
for num in range(1, 1300):
    print('AP_'+ str(num).zfill(3))
# Out:
# AP_001
# AP_002
# AP_003
# AP_004
# AP_005
# AP_006
# AP_007
# AP_008
# AP_009
# AP_010
# AP_011
# AP_012
# AP_013
# AP_014
# AP_015
# AP_016
# AP_017
# AP_018
# AP_019
# AP_020
# AP_021
# AP_022
# AP_023
# AP_024
# AP_025
# AP_026
# AP_027
# AP_028
# AP_029
# AP_030
# AP_031
# AP_032
# AP_033
# AP_034
# AP_035
# AP_036
# AP_037
# AP_038
# AP_039
# AP_040
# AP_041
# AP_042
# AP_043
# AP_044
# AP_045
# AP_046
# AP_047
# AP_048
# AP_049
# AP_050
# AP_051
# AP_052
# AP_053
# AP_054
# AP_055
# AP_056
# AP_057
# AP_058
# AP_059
# AP_060
# AP_061
# AP_062
# AP_063
# AP_064
# AP_065
# AP_066
# AP_067
# AP_068
# AP_069
# AP_070
# AP_071
# AP_072
# AP_073
# AP_074
# AP_075
# AP_076
# AP_077
# AP_078
# AP_079
# AP_080
# AP_081
# AP_082
# AP_083
# AP_084
# AP_085
# AP_086
# AP_087
# AP_088
# AP_089
# AP_090
# AP_091
# AP_092
# AP_093
# AP_094
# AP_095
# AP_096
# AP_097
# AP_098
# AP_099
# AP_100
# AP_101
# AP_102
# AP_103
# AP_104
# AP_105
# AP_106
# AP_107
# AP_108
# AP_109
# AP_110
# AP_111
# ...

# %%
'/wef'.replace('/', '_')
# Out:
# '_wef'

# %%
test = {
'a': 1,
}

# %%
test['d'] =2

# %%
test
# Out:
# {'a': 1, 'd': 2}
